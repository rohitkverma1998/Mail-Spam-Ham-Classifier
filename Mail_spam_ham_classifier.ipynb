# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from collections import Counter
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedShuffleSplit

# %%
df = pd.read_csv('spam.csv', encoding = "ISO-8859-1")
df = df[['v1','v2']]
df.head()
# Out:
#      v1                                                 v2
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 2 columns):
# v1    5572 non-null object
# v2    5572 non-null object
# dtypes: object(2)
# memory usage: 87.1+ KB

# %%
len(df["v2"])
# Out:
# 5572

# %%
len(df["v2"].unique())
# Out:
# 5169

# %% [markdown]
# ## Removing duplicates

# %%
df.drop_duplicates(subset=None, inplace=True)

# %%
len(df["v2"])
# Out:
# 5169

# %%
arr, indexes = np.unique(df[:]["v2"],return_index=True)

# %%
df_clean = df.iloc[indexes,:]

# %%
df_clean.head()
# Out:
#        v1                                                 v2
# 4024  ham                &lt;#&gt;  in mca. But not conform.
# 3014  ham   &lt;#&gt;  mins but i had to stop somewhere f...
# 4264  ham   &lt;DECIMAL&gt; m but its not a common car he...
# 2765  ham           and  picking them up from various points
# 3671  ham   came to look at the flat, seems ok, in his 50...

# %%
df_clean["v2"].head()
# Out:
# 4024                  &lt;#&gt;  in mca. But not conform.
# 3014     &lt;#&gt;  mins but i had to stop somewhere f...
# 4264     &lt;DECIMAL&gt; m but its not a common car he...
# 2765             and  picking them up from various points
# 3671     came to look at the flat, seems ok, in his 50...
# Name: v2, dtype: object

# %%
X=df_clean["v2"].values
y=df_clean["v1"].values

# %% [markdown]
# ## Remove punctuation and Remove not relevant special characters

# %%
import string
def remove_punct(message):
    for punctuation in string.punctuation:
        message = message.replace(punctuation, '')
    return message
df['v2'] = df['v2'].apply(remove_punct)
df['v2'] = df['v2'].str.replace('\W', ' ')

# %%
df.head()
# Out:
#      v1                                                 v2
# 0   ham  Go until jurong point crazy Available only in ...
# 1   ham                            Ok lar Joking wif u oni
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham        U dun say so early hor U c already then say
# 4   ham  Nah I dont think he goes to usf he lives aroun...

# %%
df.shape[0]
# Out:
# 5169

# %%
y[1]
# Out:
# 'ham'

# %%
df[df["v1"]=="ham"].count()
# Out:
# v1    4516
# v2    4516
# dtype: int64

# %%
df[df["v1"]=="spam"].count()
# Out:
# v1    653
# v2    653
# dtype: int64

# %% [markdown]
# ## Here out of 5196 data 4516 are ham so this is unbalanced distribution so we have to perform stratified split

# %%
sfs = StratifiedShuffleSplit(n_splits=1, test_size=0.3, random_state=0)
sfs.get_n_splits(X, y)
# Out:
# 1

# %%
for train_index, test_index in sfs.split(X,y):
    X_train, y_train = X[train_index], y[train_index]
    X_test, y_test= X[test_index], y[test_index]

# %% [markdown]
# ## converting strings to integer counts

# %%
all_words = {}
total_all_words = 0
for email in X_train:
    for word in email.split():
        if word not in all_words:
            all_words[word]=1
        else:
            all_words[word]+=1
for i,j in all_words.items():
    total_all_words+=j
print(total_all_words)
len(all_words)
# Out:
# 56020
# 12383

# %%
## Probability of SPAM

# %%
all_words
# Out:
# {'Big': 1,
#  'brother\x89Û÷s': 1,
#  'really': 49,
#  'scraped': 1,
#  'the': 812,
#  'barrel': 1,
#  'with': 228,
#  'this': 165,
#  'shower': 5,
#  'of': 382,
#  'social': 3,
#  'misfits': 1,
#  'Nope': 5,
#  "i'm": 54,
#  'not': 225,
#  'drivin...': 1,
#  'I': 977,
#  'neva': 8,
#  'develop': 2,
#  'da': 43,
#  'photos': 3,
#  'lei...': 10,
#  '\\Response\\"': 1,
#  'is': 496,
#  'one': 90,
#  'd': 37,
#  'powerful': 1,
#  'weapon': 1,
#  '2': 322,
#  'occupy': 2,
#  'a': 827,
#  'place': 28,
#  'in': 517,
#  'others': 6,
#  "'HEART'...": 1,
#  'So': 66,
#  'Boo.': 1,
#  "How's": 8,
#  'things?': 2,
#  "I'm": 177,
#  'back': 77,
#  'at': 217,
#  'home': 70,
#  'and': 589,
#  'little': 20,
#  'bored': 9,
#  'already': 31,
#  ':-(': 11,
#  'Sorry,': 6,
#  "I'll": 62,
#  'call': 194,
#  'later': 35,
#  'ok': 42,
#  'bye': 2,
#  '<Forwarded': 4,
#  'from': 167,
#  '88877>FREE': 1,
#  'entry': 16,
#  'into': 25,
#  'our': 87,
#  'å£250': 12,
#  'weekly': 13,
#  'comp': 7,
#  'just': 160,
#  'send': 98,
#  'word': 15,
#  'ENTER': 1,
#  'to': 1394,
#  '88877': 1,
#  'NOW.': 5,
#  '18': 12,
#  'T&C': 9,
#  'www.textcomp.com': 1,
#  'Okay,': 1,
#  'good,': 6,
#  'no': 80,
#  'problem,': 1,
#  'thanx!': 1,
#  'will': 212,
#  'reach': 18,
#  'before': 34,
#  'ten': 7,
#  'morning': 22,
#  'Yo': 9,
#  'you': 1123,
#  'around?': 4,
#  'A': 58,
#  'friend': 23,
#  "mine's": 1,
#  'lookin': 2,
#  'pick': 34,
#  'up': 184,
#  'tonight': 19,
#  'Why': 18,
#  'tired': 6,
#  'what': 107,
#  'special': 15,
#  'there': 70,
#  'had': 46,
#  'Moji': 3,
#  'i': 509,
#  'love': 76,
#  'more': 61,
#  'than': 26,
#  'words.': 2,
#  'Have': 52,
#  'rich': 3,
#  'day': 64,
#  'Lol': 29,
#  'no.': 9,
#  'Just': 79,
#  'trying': 30,
#  'make': 63,
#  'your': 359,
#  'interesting': 1,
#  'Quite': 2,
#  'lor.': 47,
#  'But': 76,
#  'dun': 29,
#  'tell': 70,
#  'him': 62,
#  'wait': 33,
#  'he': 95,
#  'get': 218,
#  'complacent...': 1,
#  'accidentally': 4,
#  'brought': 2,
#  'em': 8,
#  'box': 4,
#  'Hmm': 3,
#  '..': 7,
#  'Bits': 1,
#  'pieces': 1,
#  'lol': 4,
#  '...': 132,
#  '*sighs*': 4,
#  'Aiyah': 4,
#  'wat': 22,
#  'as': 91,
#  'long': 20,
#  'got': 124,
#  'improve': 2,
#  'can': 202,
#  'wat...': 8,
#  'The': 64,
#  "table's": 1,
#  'occupied,': 1,
#  'waiting': 28,
#  'by': 96,
#  'tree': 3,
#  'Okay': 6,
#  'same': 20,
#  'me.': 63,
#  'Well': 21,
#  'thanks': 17,
#  'for': 422,
#  'clarification': 1,
#  'Oic': 1,
#  'cos': 38,
#  'me': 384,
#  'n': 79,
#  'my': 430,
#  'sis': 13,
#  'lunch': 17,
#  'today': 32,
#  'dad': 16,
#  'went': 34,
#  'out...': 3,
#  'dunno': 9,
#  'whether': 3,
#  'eat': 20,
#  'sch': 11,
#  'or': 237,
#  'Nope...': 2,
#  'Think': 10,
#  'go': 159,
#  'it': 254,
#  'on': 312,
#  'monday...': 1,
#  'Sorry': 35,
#  'replied': 4,
#  'so': 203,
#  'late': 22,
#  'Were': 3,
#  'find': 38,
#  'Chinese': 3,
#  'food': 8,
#  'around': 31,
#  'here': 57,
#  'Good': 49,
#  'morning,': 7,
#  'Love': 16,
#  'sleep': 26,
#  'now': 122,
#  'wish': 22,
#  'great': 47,
#  'full': 14,
#  'feeling': 12,
#  'better': 23,
#  'opportunity': 2,
#  'You': 177,
#  'are': 264,
#  'last': 40,
#  'thought': 29,
#  'babe,': 12,
#  'LOVE': 14,
#  'YOU': 20,
#  '*kiss*': 3,
#  'see.': 5,
#  'When': 27,
#  'we': 150,
#  'finish': 26,
#  'have': 328,
#  'loads': 6,
#  'loans': 1,
#  'pay': 24,
#  'Please': 36,
#  'some': 74,
#  'that': 286,
#  'stock': 4,
#  'were': 40,
#  'talking': 9,
#  'about': 96,
#  'Dont': 22,
#  'forget': 12,
#  'many': 35,
#  'FREE': 54,
#  'Requests': 1,
#  '1stchoice.co.uk': 1,
#  'wish.': 3,
#  'For': 27,
#  'Information': 1,
#  '08707808226.': 1,
#  'Luck!': 2,
#  'Draw': 2,
#  'takes': 13,
#  '28th': 1,
#  'Feb': 2,
#  '06.': 1,
#  'removal': 2,
#  'STOP': 27,
#  '87239': 4,
#  'customer': 19,
#  'services': 9,
#  '08708034412': 2,
#  'Then': 33,
#  'why': 26,
#  'responding': 2,
#  'Shall': 5,
#  'exe': 1,
#  'mail': 13,
#  'id.': 2,
#  'Den': 7,
#  'e': 50,
#  'schedule': 2,
#  'b': 41,
#  'lk': 1,
#  'sun?': 1,
#  'know': 143,
#  'complain': 1,
#  'num': 4,
#  'only..bettr': 1,
#  'directly': 4,
#  'bsnl': 1,
#  'offc': 1,
#  'nd': 2,
#  'apply': 11,
#  'it..': 5,
#  'Your': 66,
#  'pussy': 1,
#  'perfect!': 1,
#  "You're": 9,
#  'gonna': 43,
#  'be': 249,
#  'way': 45,
#  'specific': 2,
#  'Do': 74,
#  'well': 31,
#  ':)all': 1,
#  'time.': 17,
#  'Thing': 1,
#  'good': 81,
#  'times': 11,
#  'ahead:': 1,
#  '5p': 1,
#  '4': 147,
#  'alfie': 2,
#  "Moon's": 3,
#  'Children': 3,
#  'need': 97,
#  'song': 8,
#  'ur': 181,
#  'mob.': 3,
#  'Tell': 20,
#  'm8s.': 3,
#  'Txt': 42,
#  'Tone': 6,
#  'charity': 5,
#  '8007': 15,
#  'Nokias': 2,
#  'Poly': 3,
#  'polys:': 2,
#  'zed': 5,
#  '08701417012': 3,
#  'profit': 3,
#  'charity.': 2,
#  'THING': 1,
#  'R': 24,
#  'GOOD': 9,
#  'THANX': 1,
#  'GOT': 5,
#  'EXAMS': 1,
#  'IN': 17,
#  'MARCH': 1,
#  'IVE': 4,
#  'DONE': 3,
#  'NO': 5,
#  'REVISION?': 1,
#  'IS': 23,
#  'FRAN': 3,
#  'STILL': 1,
#  'WITH': 8,
#  'BOYF?': 1,
#  'GOTTA': 1,
#  'INTERVIW': 1,
#  'EXETER': 1,
#  'BIT': 3,
#  'WORRIED!x': 1,
#  'dont': 64,
#  'use': 22,
#  'hook': 4,
#  'any': 75,
#  'how': 83,
#  'taking': 11,
#  'derek': 2,
#  '&amp;': 35,
#  'taylor': 2,
#  'walmart,': 1,
#  'if': 140,
#  'time': 102,
#  "you're": 30,
#  'done': 10,
#  'leave': 30,
#  'mouse': 1,
#  'desk': 1,
#  'text': 80,
#  'when': 148,
#  "priscilla's": 2,
#  'ready': 20,
#  'de': 7,
#  'shop.': 1,
#  'CDs': 3,
#  '4u:': 1,
#  'Congratulations': 8,
#  'awarded': 21,
#  'å£500': 7,
#  'CD': 4,
#  'gift': 12,
#  'vouchers': 6,
#  'å£125': 1,
#  'guaranteed': 11,
#  '&': 66,
#  'Freeentry': 1,
#  'å£100': 11,
#  'wkly': 5,
#  'draw': 24,
#  'xt': 1,
#  'MUSIC': 5,
#  '87066': 5,
#  'TnCs': 2,
#  'www.ldew.com1win150ppmx3age16': 1,
#  'HIYA': 2,
#  'STU': 1,
#  'WOT': 4,
#  'U': 207,
#  'UP': 15,
#  '2.IM': 1,
#  'SO': 8,
#  'MUCH': 4,
#  'TRUBLE': 1,
#  'AT': 16,
#  'HOME': 3,
#  'MOMENT': 1,
#  'EVONE': 1,
#  'HATES': 1,
#  'ME': 21,
#  'EVEN': 1,
#  'U!': 5,
#  'THE': 22,
#  'HELL': 1,
#  'AV': 1,
#  'NOW?': 2,
#  'Y': 9,
#  'WONT': 1,
#  'JUST': 6,
#  'TELL': 4,
#  'TEXT': 7,
#  'BCK': 1,
#  'PLEASE': 2,
#  'LUV': 4,
#  'DAN': 1,
#  'Hows': 8,
#  'watch': 26,
#  'resizing': 1,
#  'am': 110,
#  'late,so': 1,
#  'tomorrow': 36,
#  'morning.take': 1,
#  'care': 25,
#  'sweet': 13,
#  'dreams....u': 1,
#  'me...ummifying...bye.': 1,
#  'WE': 5,
#  'REGRET': 1,
#  'TO': 10,
#  'INFORM': 1,
#  'THAT': 9,
#  'NHS': 1,
#  'HAS': 1,
#  'MADE': 1,
#  'MISTAKE.U': 1,
#  'WERE': 2,
#  'NEVER': 1,
#  'ACTUALLY': 1,
#  'BORN.PLEASE': 1,
#  'REPORT': 1,
#  'YOR': 2,
#  'LOCAL': 1,
#  'HOSPITAL': 1,
#  '2B': 1,
#  'TERMINATED.WE': 1,
#  'SORRY': 3,
#  'INCONVENIENCE': 1,
#  'Well.': 3,
#  'Im': 16,
#  'computerless.': 1,
#  'Time': 5,
#  'oreo': 2,
#  'truffles': 1,
#  'Lemme': 2,
#  'To': 51,
#  'class': 22,
#  'class.': 9,
#  'Dunno': 16,
#  'lei': 3,
#  'say...': 3,
#  'Hi': 42,
#  'babe': 23,
#  'its': 72,
#  'coming': 25,
#  'even': 32,
#  'though': 9,
#  'didnt': 18,
#  'well!i': 1,
#  'wanted': 17,
#  'bed!': 2,
#  'Hope': 33,
#  'see': 69,
#  'soon': 16,
#  'kisses': 1,
#  'xxx': 6,
#  'missed': 14,
#  "let's": 2,
#  'talk': 17,
#  '07090201529': 1,
#  'Eerie': 1,
#  'Nokia': 26,
#  'tones': 15,
#  '4u,': 1,
#  'rply': 5,
#  'TONE': 5,
#  'TITLE': 2,
#  'eg': 9,
#  'DRACULA': 1,
#  'Titles:': 2,
#  'GHOST,': 1,
#  'ADDAMSFA,': 1,
#  'MUNSTERS,': 1,
#  'EXORCIST,': 1,
#  'TWILIGHT': 1,
#  'www.getzed.co.uk': 4,
#  'POBox36504W45WQ': 4,
#  '150p': 15,
#  "I've": 32,
#  'told': 42,
#  'everything': 17,
#  'stop.': 5,
#  'let': 43,
#  'her': 65,
#  'dehydrated.': 1,
#  'Really': 5,
#  'do': 159,
#  'hope': 40,
#  'work': 33,
#  'doesnt': 6,
#  'stressful.': 1,
#  'gr8': 6,
#  'day.': 32,
#  'Is': 34,
#  'changes': 3,
#  'report': 1,
#  'big?': 1,
#  'Cos': 16,
#  "i've": 18,
#  'made': 16,
#  'previous': 3,
#  'report.': 1,
#  'everywhere': 1,
#  'dirt,': 1,
#  'floor,': 2,
#  'windows,': 1,
#  'shirt.': 1,
#  'And': 67,
#  'sometimes': 2,
#  'open': 10,
#  'mouth,': 1,
#  'all': 146,
#  'comes': 8,
#  'flowing': 2,
#  'out.': 14,
#  'dream': 4,
#  'world': 13,
#  'without': 18,
#  'you,': 24,
#  'then': 97,
#  'half': 14,
#  'chores': 1,
#  'out': 136,
#  'too.': 9,
#  'joy': 1,
#  'me,': 11,
#  'lots': 11,
#  'tv': 14,
#  'shows': 27,
#  'i.ll': 8,
#  'guess': 13,
#  'like': 142,
#  'things': 34,
#  'must': 14,
#  'exist,': 1,
#  'rain,': 1,
#  'hail': 1,
#  'mist,': 1,
#  'done,': 3,
#  'become': 3,
#  'one.': 8,
#  'Wishing': 2,
#  'wonderful': 8,
#  'week.': 12,
#  'Today': 11,
#  'workin': 5,
#  'but': 192,
#  'free': 68,
#  'oso...': 3,
#  'Gee...': 2,
#  'Thgt': 1,
#  'u': 450,
#  "fren's": 1,
#  'shop': 9,
#  '?': 132,
#  'Great!': 4,
#  'How': 101,
#  'office': 11,
#  'today?': 13,
#  'HI': 11,
#  'BABE': 7,
#  'MOST': 2,
#  'LIKELY': 1,
#  'BE': 4,
#  'BED': 2,
#  'BUT': 6,
#  'IM': 14,
#  'ABOUT': 2,
#  'TONIGHT!': 1,
#  'REALLY': 4,
#  'WANNA': 3,
#  'SEE': 3,
#  'TOMORROW': 2,
#  'CALL': 17,
#  '9.': 2,
#  'XXX': 9,
#  'ass!': 1,
#  'enjoy': 12,
#  'doggy': 2,
#  'style?': 1,
#  ':)': 39,
#  'They': 23,
#  "don't": 81,
#  'put': 19,
#  'stuff': 21,
#  'roads': 1,
#  'keep': 41,
#  'getting': 36,
#  'slippery': 1,
#  'over': 36,
#  'there?': 8,
#  'Miss': 6,
#  'miss': 41,
#  'khelate': 1,
#  'kintu': 1,
#  'opponenter': 1,
#  'dhorte': 1,
#  'lage.': 1,
#  'Thats': 9,
#  'rule.': 1,
#  'One': 5,
#  'phone': 51,
#  'receiving': 2,
#  'quality': 3,
#  'wins.': 1,
#  'Camera': 3,
#  '-': 51,
#  'SiPix': 3,
#  'Digital': 3,
#  'Camera!': 3,
#  '09061221066': 2,
#  'fromm': 2,
#  'landline.': 9,
#  'Delivery': 3,
#  'within': 7,
#  '28': 2,
#  'days.': 6,
#  'take': 72,
#  "didn't": 30,
#  'callon': 1,
#  'Friday.': 1,
#  'Can': 47,
#  'assume': 2,
#  "won't": 14,
#  'year': 14,
#  'now?': 17,
#  'feel?': 1,
#  'Mr.': 2,
#  'real': 21,
#  'Valentine': 3,
#  'yo': 6,
#  'tho': 4,
#  'hardly': 2,
#  'play!!': 1,
#  'What': 62,
#  'pa': 3,
#  'me..': 4,
#  'bath:-)': 1,
#  'Edison': 1,
#  'has': 64,
#  'rightly': 1,
#  'said,': 2,
#  '\\A': 1,
#  'fool': 3,
#  'ask': 53,
#  'questions': 6,
#  'wise': 2,
#  'man': 11,
#  'answer\\"': 1,
#  'Now': 18,
#  'us': 37,
#  'speechless': 1,
#  'during': 7,
#  'ViVa..': 1,
#  'GM': 1,
#  'I\x89Û÷m': 4,
#  'going': 89,
#  'try': 21,
#  'months': 6,
#  'ha': 7,
#  'only': 91,
#  'joking': 2,
#  'now...': 6,
#  'Ard': 6,
#  '6': 14,
#  'dat': 23,
#  'K': 20,
#  'sure': 37,
#  'consent': 1,
#  'forms': 1,
#  ':V': 5,
#  'I.ll': 15,
#  'hand': 3,
#  'chat': 14,
#  'wit': 10,
#  'still': 86,
#  'meeting': 21,
#  'dinner': 14,
#  'tonight?': 9,
#  'Lmao!nice': 1,
#  '1': 37,
#  'Boo': 2,
#  'moms.': 2,
#  "She's": 4,
#  'making': 17,
#  'tortilla': 2,
#  'soup.': 1,
#  'Yummmm': 1,
#  'Pls': 28,
#  'she': 51,
#  'needs': 13,
#  'slowly': 4,
#  'vomit': 2,
#  'more.': 2,
#  '&lt;#&gt;': 178,
#  'g': 7,
#  'saw': 11,
#  'few': 25,
#  'days': 16,
#  'ago,': 1,
#  'guy': 15,
#  'wants': 10,
#  'sell': 6,
#  'wifi': 2,
#  '3g': 2,
#  '.': 125,
#  "That's": 13,
#  'blanked': 1,
#  'him.': 5,
#  'In': 25,
#  'Simpsons': 1,
#  'Movie': 1,
#  'released': 3,
#  'July': 1,
#  '2007': 1,
#  'name': 19,
#  'band': 1,
#  'died': 1,
#  'start': 15,
#  'film?': 1,
#  'A-Green': 1,
#  'Day,': 4,
#  'B-Blue': 1,
#  'C-Red': 1,
#  'Day.': 1,
#  '(Send': 1,
#  'A,': 2,
#  'B': 9,
#  'C)': 1,
#  'close': 7,
#  'Oh': 39,
#  'god!': 1,
#  'found': 12,
#  'number': 45,
#  'again!': 6,
#  'glad,': 1,
#  'xafter': 1,
#  'msgs': 4,
#  'cst': 1,
#  'std': 2,
#  'ntwk': 3,
#  'chg': 1,
#  'å£1.50': 7,
#  'stubborn': 1,
#  'am.': 3,
#  'want': 103,
#  'hospital.': 3,
#  'kept': 5,
#  'telling': 10,
#  'Mark': 3,
#  'weak': 3,
#  'sucker.': 1,
#  'Hospitals': 1,
#  'suckers.': 1,
#  'Dear': 35,
#  'Subscriber': 2,
#  'voucher': 7,
#  'entered': 3,
#  'receipt': 4,
#  'correct': 3,
#  'ans.': 2,
#  'was': 134,
#  'Elvis': 1,
#  'Presleys': 1,
#  'Birthday?': 1,
#  'TXT': 7,
#  'answer': 8,
#  '80062': 3,
#  'they': 63,
#  'oredi': 3,
#  'not...': 1,
#  'ÌÏ': 31,
#  'v': 20,
#  'ma': 2,
#  'fan...': 1,
#  'Ì_': 65,
#  'decide': 6,
#  'faster': 4,
#  'liao..': 1,
#  'This': 55,
#  'msg': 32,
#  'mobile': 68,
#  'content': 5,
#  'order': 10,
#  'It': 38,
#  'been': 79,
#  'resent': 1,
#  'attempt': 16,
#  'failed': 2,
#  'due': 4,
#  'network': 14,
#  'error': 1,
#  'Queries': 1,
#  'customersqueries@netvision.uk.com': 1,
#  'Wot': 5,
#  '2?': 2,
#  'Thout': 1,
#  'me!!': 2,
#  'bak': 4,
#  'luv': 13,
#  'where': 37,
#  'lab': 4,
#  'goggles': 1,
#  'afternoon,': 7,
#  'goes': 23,
#  'did': 44,
#  'well,': 6,
#  'boytoy': 10,
#  'think': 83,
#  'ard': 9,
#  'christmas.': 2,
#  'merry': 1,
#  "x'mas.": 1,
#  'min:)': 3,
#  'Its': 45,
#  'site': 4,
#  'simulate': 1,
#  'test.': 2,
#  'gives': 4,
#  'very': 48,
#  'tough': 5,
#  'test': 13,
#  'readiness.': 1,
#  'won': 26,
#  'å£200': 5,
#  'award': 7,
#  'å£1000': 19,
#  'cashto': 2,
#  'claim': 46,
#  'UR': 20,
#  '08000407165': 2,
#  '(18+)': 3,
#  'stop': 43,
#  'getstop': 2,
#  '88222': 2,
#  'PHP': 1,
#  'shall': 11,
#  'fine.': 10,
#  'avalarr': 1,
#  'now.': 44,
#  'Will': 23,
#  'hollalater': 1,
#  '4mths': 2,
#  'price': 9,
#  'Orange': 12,
#  'line': 14,
#  'rental': 4,
#  'latest': 15,
#  'camera': 11,
#  'phones': 5,
#  'FREE.': 4,
#  'Had': 13,
#  '11mths': 3,
#  'Call': 96,
#  'MobilesDirect': 2,
#  '08000938767': 2,
#  'update': 7,
#  'now!': 30,
#  'or2stoptxt': 2,
#  'do.': 14,
#  'Was': 12,
#  'exhausted': 2,
#  'train': 5,
#  'morning.': 10,
#  'Too': 3,
#  'much': 61,
#  'wine': 5,
#  'pie.': 1,
#  'too': 47,
#  'sore': 1,
#  'throat.': 1,
#  "It's": 27,
#  'scratches': 1,
#  'God': 6,
#  'created': 2,
#  'gap': 3,
#  'btwn': 1,
#  'fingers': 2,
#  'sum1': 1,
#  'vry': 2,
#  'fill': 3,
#  'those': 17,
#  'gaps': 1,
#  'holding': 2,
#  'hands..': 1,
#  'plz': 7,
#  'y': 13,
#  'between': 14,
#  'legs': 2,
#  '!!!': 5,
#  'already..sabarish': 1,
#  'asked': 15,
#  'go..': 1,
#  'sense': 3,
#  'unless': 5,
#  'free.': 6,
#  'If': 80,
#  'more,': 1,
#  'wikipedia.com': 1,
#  'years': 10,
#  'friendship:-)': 1,
#  'Check': 5,
#  'mail.i': 1,
#  'mailed': 1,
#  'varma': 1,
#  'copy': 4,
#  'regarding': 3,
#  'membership.take': 1,
#  'care.insha': 1,
#  'allah.': 1,
#  'Hi.': 6,
#  '||': 8,
#  '|': 5,
#  'join': 13,
#  'sts': 1,
#  'later?': 6,
#  'Meeting': 2,
#  'them': 42,
#  'five.': 1,
#  'after': 47,
#  'Thanks': 30,
#  'My': 46,
#  'trip': 14,
#  'quite': 23,
#  'tiring': 1,
#  'Uni': 1,
#  'starts': 4,
#  "it's": 32,
#  'modules': 2,
#  'jus': 15,
#  'concentrating': 1,
#  'final': 11,
#  'yr': 10,
#  'project.': 3,
#  'Probably': 7,
#  'not,': 7,
#  'almost': 8,
#  'gas': 9,
#  'cash': 31,
#  '-PLS': 1,
#  'bootydelious': 1,
#  '(32/F)': 1,
#  'inviting': 4,
#  'friend.': 6,
#  'Reply': 35,
#  'YES-434': 1,
#  'NO-434': 1,
#  'See': 18,
#  'her:': 3,
#  'www.SMS.ac/u/bootydelious': 1,
#  'STOP?': 4,
#  'Send': 19,
#  'FRND': 4,
#  '62468': 4,
#  'Ok.': 14,
#  'should': 48,
#  'buy.': 2,
#  'wondering': 4,
#  'would': 51,
#  'okay': 2,
#  'uncle': 4,
#  'john': 3,
#  'nigeria': 3,
#  'r': 78,
#  'here.': 8,
#  'That': 24,
#  'dollars': 2,
#  '2years': 1,
#  'sent': 39,
#  'strain': 1,
#  'plan': 12,
#  'every': 43,
#  'dime': 2,
#  'gives.': 1,
#  'Every': 5,
#  'expect': 3,
#  'anything': 37,
#  'practical.': 1,
#  'Something': 3,
#  'that.': 15,
#  'bold': 5,
#  'bb': 4,
#  'torch': 3,
#  'Pick': 2,
#  'bout': 9,
#  '7.30ish?': 1,
#  'going?': 5,
#  'Alrite': 1,
#  'jod': 1,
#  'hows': 3,
#  'revision': 1,
#  'goin?': 2,
#  'Keris': 1,
#  'bin': 4,
#  'doin': 3,
#  ...}

# %% [markdown]
# ## obtain frequency of the words

# %%
uniq = []
freq_ham = {}
freq_spam = {}
total_ham = 0
total_spam = 0
for i,email in enumerate(X_train):
    if y_train[i]=="ham":
        for word in email.split():
            if word not in freq_ham:
                freq_ham[word]=1
            else:
                freq_ham[word]+=1
    else:
        for word in email.split():
            if word not in freq_spam:
                freq_spam[word]=1
            else:
                freq_spam[word]+=1

# %%
for i,j in freq_spam.items():
    total_spam+=j
print(total_spam)
for i,j in freq_ham.items():
    total_ham+=j
print(total_ham)
# Out:
# 10861
# 45159

# %%
len(freq_spam)
# Out:
# 3421

# %%
len(freq_ham)
# Out:
# 9905

# %%
freq_spam
# Out:
# {'<Forwarded': 4,
#  'from': 68,
#  '88877>FREE': 1,
#  'entry': 16,
#  'into': 5,
#  'our': 52,
#  'å£250': 12,
#  'weekly': 13,
#  'comp': 6,
#  'just': 28,
#  'send': 27,
#  'the': 113,
#  'word': 7,
#  'ENTER': 1,
#  'to': 376,
#  '88877': 1,
#  'NOW.': 4,
#  '18': 12,
#  'T&C': 9,
#  'www.textcomp.com': 1,
#  'Dont': 2,
#  'forget': 2,
#  'you': 98,
#  'can': 16,
#  'place': 3,
#  'as': 9,
#  'many': 3,
#  'FREE': 53,
#  'Requests': 1,
#  'with': 65,
#  '1stchoice.co.uk': 1,
#  'wish.': 2,
#  'For': 16,
#  'more': 10,
#  'Information': 1,
#  'call': 103,
#  '08707808226.': 1,
#  'Good': 6,
#  'Luck!': 2,
#  'Draw': 1,
#  'takes': 2,
#  '28th': 1,
#  'Feb': 1,
#  '06.': 1,
#  'removal': 2,
#  'STOP': 27,
#  '87239': 4,
#  'customer': 17,
#  'services': 9,
#  '08708034412': 2,
#  '5p': 1,
#  '4': 52,
#  'alfie': 2,
#  "Moon's": 3,
#  'Children': 3,
#  'in': 40,
#  'need': 5,
#  'song': 3,
#  'on': 77,
#  'ur': 68,
#  'mob.': 3,
#  'Tell': 3,
#  'm8s.': 3,
#  'Txt': 39,
#  'Tone': 6,
#  'charity': 5,
#  '8007': 15,
#  'for': 115,
#  'Nokias': 2,
#  'or': 107,
#  'Poly': 3,
#  'polys:': 2,
#  'zed': 5,
#  '08701417012': 3,
#  'profit': 3,
#  '2': 118,
#  'charity.': 2,
#  'CDs': 3,
#  '4u:': 1,
#  'Congratulations': 7,
#  'awarded': 21,
#  'å£500': 7,
#  'of': 48,
#  'CD': 4,
#  'gift': 9,
#  'vouchers': 6,
#  'å£125': 1,
#  'guaranteed': 11,
#  '&': 58,
#  'Freeentry': 1,
#  'å£100': 11,
#  'wkly': 5,
#  'draw': 20,
#  'xt': 1,
#  'MUSIC': 5,
#  '87066': 5,
#  'TnCs': 2,
#  'www.ldew.com1win150ppmx3age16': 1,
#  'Sorry': 1,
#  'I': 14,
#  'missed': 1,
#  'your': 123,
#  "let's": 2,
#  'talk': 1,
#  'when': 7,
#  'have': 79,
#  'time.': 2,
#  "I'm": 4,
#  '07090201529': 1,
#  'Eerie': 1,
#  'Nokia': 25,
#  'tones': 15,
#  '4u,': 1,
#  'rply': 3,
#  'TONE': 5,
#  'TITLE': 2,
#  'eg': 9,
#  'DRACULA': 1,
#  'Titles:': 2,
#  'GHOST,': 1,
#  'ADDAMSFA,': 1,
#  'MUNSTERS,': 1,
#  'EXORCIST,': 1,
#  'TWILIGHT': 1,
#  'www.getzed.co.uk': 4,
#  'POBox36504W45WQ': 4,
#  '150p': 15,
#  'Camera': 2,
#  '-': 34,
#  'You': 54,
#  'are': 45,
#  'a': 203,
#  'SiPix': 3,
#  'Digital': 3,
#  'Camera!': 3,
#  '09061221066': 2,
#  'fromm': 2,
#  'landline.': 9,
#  'Delivery': 3,
#  'within': 4,
#  '28': 2,
#  'days.': 2,
#  'In': 1,
#  'The': 13,
#  'Simpsons': 1,
#  'Movie': 1,
#  'released': 1,
#  'July': 1,
#  '2007': 1,
#  'name': 6,
#  'band': 1,
#  'that': 14,
#  'died': 1,
#  'at': 19,
#  'start': 2,
#  'film?': 1,
#  'A-Green': 1,
#  'Day,': 2,
#  'B-Blue': 1,
#  'C-Red': 1,
#  'Day.': 1,
#  '(Send': 1,
#  'A,': 2,
#  'B': 4,
#  'C)': 1,
#  'Oh': 1,
#  'my': 7,
#  'god!': 1,
#  "I've": 1,
#  'found': 1,
#  'number': 17,
#  'again!': 1,
#  'so': 10,
#  'glad,': 1,
#  'text': 41,
#  'me': 16,
#  'back': 12,
#  'xafter': 1,
#  'this': 32,
#  'msgs': 1,
#  'cst': 1,
#  'std': 2,
#  'ntwk': 3,
#  'chg': 1,
#  'å£1.50': 7,
#  'Dear': 15,
#  'Subscriber': 2,
#  'voucher': 6,
#  'will': 25,
#  'b': 5,
#  'entered': 3,
#  'receipt': 2,
#  'correct': 2,
#  'ans.': 2,
#  'When': 3,
#  'was': 9,
#  'Elvis': 1,
#  'Presleys': 1,
#  'Birthday?': 1,
#  'TXT': 5,
#  'answer': 4,
#  '80062': 3,
#  'This': 27,
#  'msg': 10,
#  'is': 89,
#  'mobile': 58,
#  'content': 5,
#  'order': 4,
#  'It': 1,
#  'has': 19,
#  'been': 28,
#  'resent': 1,
#  'previous': 1,
#  'attempt': 16,
#  'failed': 1,
#  'due': 1,
#  'network': 13,
#  'error': 1,
#  'Queries': 1,
#  'customersqueries@netvision.uk.com': 1,
#  'won': 26,
#  'å£200': 5,
#  'award': 7,
#  'even': 5,
#  'å£1000': 19,
#  'cashto': 2,
#  'claim': 46,
#  'UR': 16,
#  'free': 36,
#  '08000407165': 2,
#  '(18+)': 3,
#  'stop': 29,
#  'getstop': 2,
#  '88222': 2,
#  'PHP': 1,
#  '4mths': 2,
#  'half': 2,
#  'price': 5,
#  'Orange': 12,
#  'line': 9,
#  'rental': 4,
#  'latest': 15,
#  'camera': 10,
#  'phones': 5,
#  'FREE.': 4,
#  'Had': 11,
#  'phone': 16,
#  '11mths': 3,
#  '?': 4,
#  'Call': 84,
#  'MobilesDirect': 2,
#  '08000938767': 2,
#  'update': 5,
#  'now!': 28,
#  'or2stoptxt': 2,
#  '-PLS': 1,
#  'bootydelious': 1,
#  '(32/F)': 1,
#  'inviting': 4,
#  'be': 30,
#  'her': 4,
#  'friend.': 4,
#  'Reply': 32,
#  'YES-434': 1,
#  'NO-434': 1,
#  'See': 6,
#  'her:': 3,
#  'www.SMS.ac/u/bootydelious': 1,
#  'STOP?': 4,
#  'Send': 12,
#  'FRND': 4,
#  '62468': 4,
#  '*': 1,
#  'FREE*': 1,
#  'POLYPHONIC': 2,
#  'RINGTONE': 3,
#  'Text': 23,
#  'SUPER': 1,
#  '87131': 3,
#  'get': 27,
#  'POLY': 5,
#  'week': 15,
#  '16': 14,
#  'SN': 1,
#  'PoBox202': 1,
#  'NR31': 1,
#  '7ZS': 1,
#  'subscription': 3,
#  '450pw': 1,
#  'CLAIRE': 2,
#  'here': 3,
#  'am': 6,
#  'havin': 1,
#  'borin': 1,
#  'time': 9,
#  'now': 41,
#  'alone': 2,
#  'U': 43,
#  'wanna': 4,
#  'cum': 3,
#  'over': 4,
#  '2nite?': 2,
#  'Chat': 5,
#  '09099725823': 1,
#  'hope': 2,
#  'C': 10,
#  'Luv': 4,
#  'xx': 3,
#  'Callså£1/minmoremobsEMSPOBox45PO139WA': 2,
#  '10': 4,
#  'mths?': 1,
#  'Update': 8,
#  'camera/video': 1,
#  'Save': 2,
#  'å£s': 1,
#  'Free': 20,
#  'texts/weekend': 1,
#  'calls.': 3,
#  'YES': 8,
#  'callback': 1,
#  'orno': 1,
#  'opt': 7,
#  'out': 22,
#  'Thanks': 10,
#  'Vote.': 1,
#  'Now': 4,
#  'sing': 1,
#  'along': 1,
#  'stars': 1,
#  'Karaoke': 1,
#  'mobile.': 2,
#  'link': 5,
#  'reply': 43,
#  'SING': 1,
#  'now.': 9,
#  '74355': 1,
#  'XMAS': 2,
#  'iscoming': 1,
#  'either': 4,
#  'r': 9,
#  'txt': 37,
#  'TnC': 1,
#  'Someone': 4,
#  'know': 10,
#  'asked': 4,
#  'dating': 9,
#  'service': 25,
#  'contact': 41,
#  'you!': 8,
#  'Cant': 3,
#  'guess': 1,
#  'who?': 3,
#  'CALL': 13,
#  '09058095107': 1,
#  'NOW': 13,
#  'all': 13,
#  'revealed.': 4,
#  'POBox': 5,
#  '7,': 1,
#  'S3XY': 1,
#  'We': 22,
#  'tried': 11,
#  're': 7,
#  'sms': 3,
#  'video': 9,
#  '750': 14,
#  'mins': 11,
#  'UNLIMITED': 5,
#  'TEXT': 5,
#  '+': 10,
#  'camcorder': 4,
#  '08000930705': 10,
#  'FIRST': 1,
#  'poly': 2,
#  'GET': 2,
#  'true': 1,
#  'tone!': 1,
#  'Help?': 3,
#  '0845': 2,
#  '2814032': 1,
#  'after': 2,
#  '1st': 17,
#  'free,': 2,
#  '3xå£150pw': 1,
#  'eå£nd': 1,
#  'msg:': 1,
#  'Single?': 1,
#  'Find': 1,
#  'partner': 4,
#  'area!': 1,
#  '1000s': 3,
#  'real': 6,
#  'people': 2,
#  'waiting': 9,
#  'chat': 7,
#  'now!Send': 1,
#  'CHAT': 10,
#  '62220Cncl': 1,
#  'STOPCS': 1,
#  '08717890890å£1.50': 1,
#  'per': 25,
#  'Do': 10,
#  'want': 11,
#  'new': 25,
#  'handset?': 3,
#  'anytime': 9,
#  'any': 15,
#  'mins?': 5,
#  'Half': 5,
#  'Price': 4,
#  'Line': 1,
#  'Rental?': 1,
#  'Camcorder?': 4,
#  'delivery': 8,
#  'tomorrow': 6,
#  'Hottest': 1,
#  'pics': 4,
#  'straight': 2,
#  'phone!!': 1,
#  'getting': 3,
#  'Wet': 1,
#  'and': 79,
#  'Wanting,': 1,
#  'PICS': 1,
#  '89555': 2,
#  'costs': 1,
#  'textoperator': 2,
#  'g696ga': 2,
#  'XxX': 2,
#  'FreeMsg': 2,
#  'Why': 2,
#  "haven't": 1,
#  'replied': 1,
#  'text?': 1,
#  'Randy,': 1,
#  'sexy,': 1,
#  'female': 1,
#  'live': 9,
#  'local.': 1,
#  'hear': 2,
#  'u.': 5,
#  'Netcollex': 2,
#  'Ltd': 2,
#  '08700621170150p': 1,
#  'Stop': 4,
#  'end': 5,
#  'Voucher': 5,
#  'Holder,': 4,
#  'To': 47,
#  'weeks': 6,
#  'offer,': 4,
#  'PC': 4,
#  'please': 13,
#  'go': 11,
#  'http://www.wtlp.co.uk/text.': 1,
#  'Ts&Cs': 7,
#  'apply.': 8,
#  '83039': 1,
#  '62735=å£450': 1,
#  'UK': 4,
#  'Break': 4,
#  'AccommodationVouchers': 1,
#  'terms': 2,
#  'conditions': 2,
#  'mustprovide': 1,
#  'which': 2,
#  '15541': 1,
#  '0776xxxxxxx': 2,
#  "U've": 5,
#  'invited': 5,
#  'XCHAT.': 4,
#  'final': 10,
#  'u!': 5,
#  '86688': 11,
#  '150p/MsgrcvdHG/Suite342/2Lands/Row/W1J6HL': 4,
#  'LDN': 4,
#  '18yrs': 3,
#  'Dorothy@kiefer.com': 1,
#  '(Bank': 1,
#  'Granite': 1,
#  'issues': 1,
#  'Strong-Buy)': 1,
#  'EXPLOSIVE': 1,
#  'PICK': 1,
#  'FOR': 6,
#  'OUR': 1,
#  'MEMBERS': 1,
#  '*****UP': 1,
#  'OVER': 1,
#  '300%': 1,
#  '***********': 1,
#  'Nasdaq': 1,
#  'Symbol': 1,
#  'CDGT': 1,
#  'That': 1,
#  '$5.00': 1,
#  'per..': 1,
#  'URGENT!': 20,
#  'Your': 49,
#  'Mobile': 16,
#  'No': 7,
#  '07808726822': 1,
#  'å£2,000': 8,
#  'Bonus': 11,
#  'Caller': 9,
#  'Prize': 10,
#  '02/09/03!': 2,
#  '2nd': 13,
#  'YOU!': 8,
#  '0871-872-9758': 1,
#  'BOX95QU': 3,
#  'http//tms.': 1,
#  'widelive.com/index.': 1,
#  'wml?id=820554ad0a1705572711&first=trueåÁC': 1,
#  'RingtoneåÁ': 1,
#  'Not': 1,
#  'heard': 1,
#  'U4': 1,
#  'while.': 1,
#  'night': 3,
#  'knickers': 1,
#  'on.': 1,
#  'Make': 1,
#  'beg': 1,
#  'it': 13,
#  'like': 10,
#  'did': 1,
#  'last': 3,
#  '01223585236': 1,
#  'XX': 1,
#  'Nikiyu4.net': 1,
#  'Please': 18,
#  '08712402972': 1,
#  'immediately': 3,
#  'there': 6,
#  'an': 12,
#  'urgent': 3,
#  'message': 14,
#  'Our': 6,
#  'by': 23,
#  'someone': 5,
#  'shy!': 1,
#  '09058091870': 1,
#  'POBox84,': 1,
#  'M26': 2,
#  '3UZ': 2,
#  'Dave': 2,
#  'notice': 3,
#  'collect': 9,
#  '4*': 14,
#  'Tenerife': 6,
#  'Holiday': 13,
#  '#5000': 3,
#  'CASH': 7,
#  'award!': 3,
#  '09061743806': 2,
#  'TCs': 2,
#  'SAE': 11,
#  'Box326': 2,
#  'CW25WX': 3,
#  '150ppm': 17,
#  'Jamster!': 1,
#  'wallpaper': 1,
#  'HEART': 1,
#  '88888': 1,
#  'only.': 5,
#  'Need': 3,
#  '08701213186.': 1,
#  'ringtone': 10,
#  'order,': 5,
#  'ref': 2,
#  'K718.': 1,
#  'charged': 10,
#  'å£4.50.': 3,
#  'Should': 5,
#  'tone': 13,
#  'not': 11,
#  'arrive': 6,
#  '09065069120': 1,
#  'trying': 10,
#  'U.': 6,
#  'Todays': 8,
#  'shows': 23,
#  'å£800': 4,
#  'prize': 23,
#  'GUARANTEED.': 11,
#  '09050001295': 1,
#  'land': 9,
#  'line.': 8,
#  'Claim': 17,
#  'A21.': 1,
#  'Valid': 11,
#  '12hrs': 9,
#  'only': 25,
#  'PASS': 1,
#  '69669': 1,
#  'polyphonic': 1,
#  'ringtones.': 1,
#  'Normal': 1,
#  'gprs': 1,
#  'charges': 2,
#  'apply': 9,
#  'Enjoy': 4,
#  'Last': 7,
#  "weekend's": 2,
#  'cash': 24,
#  'Spanish': 2,
#  'holiday!': 1,
#  '09050000332': 1,
#  'claim.': 1,
#  'T&C:': 1,
#  'RSTM,': 1,
#  'SW7': 1,
#  '3SS.': 1,
#  'YOUR': 5,
#  'CHANCE': 2,
#  'TO': 3,
#  'BE': 2,
#  'ON': 6,
#  'A': 10,
#  'REALITY': 2,
#  'FANTASY': 2,
#  'SHOW': 2,
#  '=': 5,
#  '08707509020': 3,
#  'Just': 15,
#  '20p': 3,
#  'min': 4,
#  'NTT': 5,
#  'Ltd,': 4,
#  'PO': 14,
#  'Box': 10,
#  '1327': 3,
#  'Croydon': 3,
#  'CR9': 3,
#  '5WB': 3,
#  '0870': 4,
#  'national': 5,
#  'rate': 5,
#  'call.': 1,
#  'BANNEDUK': 1,
#  'see!': 1,
#  'cost': 4,
#  '18+': 11,
#  'XXX': 4,
#  'account': 2,
#  'credited': 1,
#  '500': 13,
#  'Messages.': 1,
#  'activate,': 1,
#  'word:': 5,
#  'CREDIT': 1,
#  'No:': 8,
#  '80488': 2,
#  'T&Cs': 12,
#  'www.80488.biz': 1,
#  'SIX': 1,
#  'chances': 1,
#  'win': 18,
#  'CASH!': 1,
#  'From': 5,
#  '100': 10,
#  '20,000': 1,
#  'pounds': 11,
#  'txt>': 1,
#  'CSH11': 1,
#  '87575.': 2,
#  'Cost': 10,
#  '150p/day,': 1,
#  '6days,': 1,
#  '16+': 12,
#  'TsandCs': 1,
#  'HL': 3,
#  'info': 2,
#  'Want': 10,
#  'Video': 6,
#  'rental?': 1,
#  '2/2': 1,
#  '146tf150p': 1,
#  'City': 3,
#  'could': 5,
#  'WIN': 9,
#  'Summer': 3,
#  'Shopping': 3,
#  'spree': 4,
#  'every': 18,
#  'WK.': 3,
#  'STORE': 3,
#  '88039.SkilGme.TsCs087147403231Winawk!Age16+å£1.50perWKsub': 1,
#  'Moby': 1,
#  'Pub': 1,
#  'Quiz.Win': 1,
#  'High': 1,
#  'Street': 1,
#  'if': 8,
#  'u': 25,
#  'who': 23,
#  'Duchess': 1,
#  'Cornwall': 1,
#  'be?': 1,
#  'first': 3,
#  '82277.unsub': 1,
#  '008704050406': 1,
#  'SP': 2,
#  'Welcome!': 1,
#  'AGE': 4,
#  'GENDER': 1,
#  'begin.': 1,
#  'e.g': 1,
#  '24M': 1,
#  'meet': 4,
#  'sexy': 7,
#  'today.': 1,
#  'find': 9,
#  'date': 3,
#  'flirt': 1,
#  'its': 3,
#  'up': 13,
#  'Join': 6,
#  '10p.': 1,
#  'REPLY': 1,
#  'NAME': 3,
#  'Sam': 1,
#  '25.': 1,
#  '-msg': 1,
#  'recd@thirtyeight': 1,
#  'pence': 2,
#  'Hello.': 1,
#  'some': 4,
#  'posh': 1,
#  'birds': 1,
#  'chaps': 1,
#  'user': 3,
#  'trial': 1,
#  'prods': 1,
#  'champneys.': 1,
#  'Can': 3,
#  'i': 3,
#  'put': 1,
#  'down?': 1,
#  'address': 2,
#  'dob': 1,
#  'asap.': 1,
#  'Ta': 1,
#  '447801259231': 1,
#  'secret': 5,
#  'admirer': 4,
#  'looking': 6,
#  'make': 6,
#  'U-find': 5,
#  'they': 7,
#  'R*reveal': 5,
#  'thinks': 6,
#  'special-call': 5,
#  '09058094597': 1,
#  'Goal!': 1,
#  'Arsenal': 2,
#  '(Henry,': 1,
#  '7': 1,
#  'v': 2,
#  'Liverpool': 1,
#  'Henry': 1,
#  'scores': 1,
#  'simple': 1,
#  'shot': 1,
#  '6': 3,
#  'yards': 1,
#  'pass': 2,
#  'Bergkamp': 1,
#  'give': 4,
#  'goal': 1,
#  'margin': 1,
#  '78': 1,
#  'mins.': 1,
#  'good': 3,
#  'friend': 3,
#  'WON': 9,
#  'Xmas': 5,
#  'prize.': 10,
#  'easy,': 5,
#  '08712103738': 1,
#  'NOW!': 7,
#  'Only': 7,
#  '10p': 9,
#  'minute.': 3,
#  'BT-national-rate': 4,
#  'GAME.': 1,
#  'Get': 15,
#  'Rayman': 1,
#  'Golf': 1,
#  'O2': 3,
#  'Games': 2,
#  'Arcade.': 2,
#  'games': 4,
#  'settings.': 1,
#  'POST,': 1,
#  'then': 3,
#  'save': 1,
#  'activ8.': 1,
#  'Press': 1,
#  '0': 1,
#  'key': 1,
#  'Termsapply': 1,
#  '80488.': 1,
#  'messages': 4,
#  'valid': 2,
#  'until': 4,
#  '31': 1,
#  'December': 4,
#  '2005.': 2,
#  '87077:': 1,
#  'Kick': 1,
#  'off': 2,
#  'season': 1,
#  '2wks': 1,
#  'goals': 1,
#  'news': 3,
#  'mobile!': 4,
#  'club': 5,
#  '87077': 7,
#  'VILLA': 1,
#  'logo': 4,
#  'lover': 2,
#  'names': 2,
#  'joined': 2,
#  'heart.': 2,
#  'LOVE': 4,
#  'NAME1': 2,
#  'NAME2': 2,
#  'MOBNO': 2,
#  'ADAM': 2,
#  'EVE': 2,
#  '07123456789': 2,
#  'Yahoo!': 2,
#  'TxtNO': 2,
#  'no': 12,
#  'ads': 2,
#  '150p.': 1,
#  'FreeMSG': 1,
#  'mini': 1,
#  'DIGITAL': 1,
#  'CAMERA,': 1,
#  'SNAP': 1,
#  'prize!': 3,
#  '(quizclub': 1,
#  'Opt': 1,
#  'out?': 1,
#  '80122300p/wk': 1,
#  'SP:RWM': 1,
#  'Ph:08704050406)': 1,
#  'Urgent': 4,
#  'complimentary': 9,
#  'trip': 3,
#  'EuroDisinc': 1,
#  'Trav,': 1,
#  'Aco&Entry41': 1,
#  'Or': 1,
#  'å£1000.': 1,
#  'DIS': 1,
#  '87121': 2,
#  '18+6*å£1.50(moreFrmMob.': 1,
#  'ShrAcomOrSglSuplt)10,': 1,
#  'LS1': 1,
#  '3AJ': 1,
#  'Auction': 2,
#  'round': 1,
#  '4.': 2,
#  'highest': 1,
#  'bid': 4,
#  'å£54.': 1,
#  'Next': 2,
#  'maximum': 1,
#  'å£71.': 1,
#  'bid,': 1,
#  'BIDS': 1,
#  'e.': 2,
#  'g.': 2,
#  '(to': 1,
#  'å£10)': 1,
#  '83383.': 1,
#  'luck.': 1,
#  'week!': 6,
#  'No1': 3,
#  'mob': 7,
#  'NOKIA': 7,
#  'txting': 5,
#  'tell': 7,
#  'mates': 2,
#  '36504': 3,
#  'W4': 1,
#  '5WQ': 1,
#  'norm': 2,
#  '150p/tone': 1,
#  'WELL': 1,
#  'DONE!': 1,
#  'Costa': 3,
#  'Del': 4,
#  'Sol': 3,
#  'å£5000': 6,
#  'await': 11,
#  'collection.': 7,
#  '09050090044': 2,
#  'toClaim.': 2,
#  'SAE,': 2,
#  'TCs,': 1,
#  'POBox334,': 2,
#  'Stockport,': 2,
#  'SK38xh,': 2,
#  'Costå£1.50/pm,': 2,
#  'Max10mins': 2,
#  'Spook': 2,
#  'Halloween': 3,
#  'collection': 9,
#  'pic': 3,
#  'plus': 3,
#  'eerie': 3,
#  'tone,': 4,
#  'CARD': 3,
#  'SPOOK': 3,
#  '08701417012150p': 2,
#  'logo/pic': 2,
#  'Phony': 1,
#  'å£350': 6,
#  'Voda': 2,
#  'numbers': 5,
#  'ending': 4,
#  'XXXX': 1,
#  'selected': 13,
#  'receive': 15,
#  'award.': 7,
#  'If': 7,
#  'match': 2,
#  '08712300220': 3,
#  'quoting': 2,
#  'code': 5,
#  '3100': 1,
#  'standard': 3,
#  'rates': 4,
#  'app': 2,
#  '09050000460': 1,
#  'J89.': 1,
#  'po': 1,
#  'box245c2150pm': 1,
#  'Will': 3,
#  'dream': 1,
#  'soon?': 1,
#  'Is': 1,
#  'career': 1,
#  'flyng': 1,
#  'start?': 1,
#  'HORO': 2,
#  'followed': 1,
#  'star': 1,
#  'sign,': 1,
#  'ARIES': 1,
#  'Hi': 3,
#  'babe': 3,
#  'Chloe,': 1,
#  'how': 3,
#  'u?': 2,
#  'smashed': 1,
#  'saturday': 1,
#  'night,': 1,
#  'great!': 1,
#  'How': 3,
#  'weekend?': 1,
#  'missing': 1,
#  'me?': 1,
#  'visionsms.com': 2,
#  '150p/text': 1,
#  'Guess': 3,
#  '09058091854': 1,
#  'BOX385': 1,
#  'M6': 1,
#  '6WU': 1,
#  '09058094594': 1,
#  '+123': 1,
#  "week's": 2,
#  'competition': 2,
#  'å£1450': 2,
#  '09050002311': 1,
#  'b4280703.': 1,
#  'T&Cs/stop': 2,
#  'SMS': 10,
#  '08718727868.': 1,
#  'Over': 1,
#  'ASKED': 1,
#  '3MOBILE': 1,
#  'IF': 1,
#  'CHATLINES': 1,
#  'INCLU': 1,
#  'IN': 3,
#  'MINS.': 1,
#  'INDIA': 1,
#  'CUST': 1,
#  'SERVs': 1,
#  'SED': 1,
#  'YES.': 1,
#  'L8ER': 1,
#  'GOT': 1,
#  ...}

# %%
freq_ham
# Out:
# {'Big': 1,
#  'brother\x89Û÷s': 1,
#  'really': 48,
#  'scraped': 1,
#  'the': 699,
#  'barrel': 1,
#  'with': 163,
#  'this': 133,
#  'shower': 5,
#  'of': 334,
#  'social': 3,
#  'misfits': 1,
#  'Nope': 5,
#  "i'm": 54,
#  'not': 214,
#  'drivin...': 1,
#  'I': 963,
#  'neva': 8,
#  'develop': 2,
#  'da': 43,
#  'photos': 3,
#  'lei...': 10,
#  '\\Response\\"': 1,
#  'is': 407,
#  'one': 86,
#  'd': 37,
#  'powerful': 1,
#  'weapon': 1,
#  '2': 204,
#  'occupy': 2,
#  'a': 624,
#  'place': 25,
#  'in': 477,
#  'others': 6,
#  "'HEART'...": 1,
#  'So': 65,
#  'Boo.': 1,
#  "How's": 8,
#  'things?': 2,
#  "I'm": 173,
#  'back': 65,
#  'at': 198,
#  'home': 69,
#  'and': 510,
#  'little': 19,
#  'bored': 9,
#  'already': 30,
#  ':-(': 11,
#  'Sorry,': 6,
#  "I'll": 62,
#  'call': 91,
#  'later': 35,
#  'ok': 40,
#  'bye': 2,
#  'Okay,': 1,
#  'good,': 6,
#  'no': 68,
#  'problem,': 1,
#  'thanx!': 1,
#  'will': 187,
#  'reach': 15,
#  'before': 32,
#  'ten': 7,
#  'morning': 22,
#  'Yo': 9,
#  'you': 1025,
#  'around?': 4,
#  'A': 48,
#  'friend': 20,
#  "mine's": 1,
#  'lookin': 2,
#  'to': 1018,
#  'pick': 34,
#  'up': 171,
#  'tonight': 19,
#  'Why': 16,
#  'tired': 6,
#  'what': 100,
#  'special': 13,
#  'there': 64,
#  'had': 46,
#  'Moji': 3,
#  'i': 506,
#  'love': 74,
#  'more': 51,
#  'than': 24,
#  'words.': 2,
#  'Have': 52,
#  'rich': 3,
#  'day': 63,
#  'Lol': 29,
#  'no.': 8,
#  'Just': 64,
#  'trying': 20,
#  'make': 57,
#  'your': 236,
#  'interesting': 1,
#  'Quite': 2,
#  'lor.': 47,
#  'But': 76,
#  'dun': 29,
#  'tell': 63,
#  'him': 62,
#  'wait': 33,
#  'he': 95,
#  'get': 191,
#  'complacent...': 1,
#  'accidentally': 4,
#  'brought': 2,
#  'em': 7,
#  'box': 3,
#  'Hmm': 3,
#  '..': 7,
#  'Bits': 1,
#  'pieces': 1,
#  'lol': 4,
#  '...': 132,
#  '*sighs*': 4,
#  'Aiyah': 4,
#  'wat': 22,
#  'as': 82,
#  'long': 20,
#  'got': 122,
#  'improve': 2,
#  'can': 186,
#  'wat...': 8,
#  'The': 51,
#  "table's": 1,
#  'occupied,': 1,
#  'waiting': 19,
#  'by': 73,
#  'tree': 3,
#  'Okay': 6,
#  'same': 20,
#  'me.': 60,
#  'Well': 21,
#  'thanks': 16,
#  'for': 307,
#  'clarification': 1,
#  'Oic': 1,
#  'cos': 38,
#  'me': 368,
#  'n': 73,
#  'my': 423,
#  'sis': 13,
#  'lunch': 17,
#  'today': 31,
#  'dad': 16,
#  'went': 34,
#  'out...': 3,
#  'dunno': 9,
#  'whether': 3,
#  'eat': 20,
#  'sch': 11,
#  'or': 130,
#  'Nope...': 2,
#  'Think': 10,
#  'go': 148,
#  'it': 241,
#  'on': 235,
#  'monday...': 1,
#  'Sorry': 34,
#  'replied': 3,
#  'so': 193,
#  'late': 22,
#  'Were': 3,
#  'find': 29,
#  'Chinese': 3,
#  'food': 8,
#  'around': 31,
#  'here': 54,
#  'Good': 43,
#  'morning,': 7,
#  'Love': 16,
#  'sleep': 26,
#  'now': 81,
#  'wish': 22,
#  'great': 43,
#  'full': 14,
#  'feeling': 11,
#  'better': 23,
#  'opportunity': 2,
#  'You': 123,
#  'are': 219,
#  'last': 37,
#  'thought': 28,
#  'babe,': 11,
#  'LOVE': 10,
#  'YOU': 15,
#  '*kiss*': 3,
#  'see.': 5,
#  'When': 24,
#  'we': 143,
#  'finish': 26,
#  'have': 249,
#  'loads': 6,
#  'loans': 1,
#  'pay': 23,
#  'Please': 18,
#  'some': 70,
#  'that': 272,
#  'stock': 4,
#  'were': 39,
#  'talking': 9,
#  'about': 93,
#  'Then': 32,
#  'why': 23,
#  'responding': 2,
#  'Shall': 5,
#  'send': 71,
#  'exe': 1,
#  'mail': 13,
#  'id.': 2,
#  'Den': 7,
#  'e': 50,
#  'schedule': 2,
#  'b': 36,
#  'lk': 1,
#  'sun?': 1,
#  'know': 133,
#  'complain': 1,
#  'num': 4,
#  'only..bettr': 1,
#  'directly': 4,
#  'bsnl': 1,
#  'offc': 1,
#  'nd': 2,
#  'apply': 2,
#  'it..': 5,
#  'Your': 17,
#  'pussy': 1,
#  'perfect!': 1,
#  "You're": 8,
#  'gonna': 43,
#  'be': 219,
#  'way': 45,
#  'specific': 2,
#  'Do': 64,
#  'well': 31,
#  ':)all': 1,
#  'time.': 15,
#  'Thing': 1,
#  'good': 78,
#  'times': 11,
#  'ahead:': 1,
#  'THING': 1,
#  'R': 20,
#  'GOOD': 9,
#  'THANX': 1,
#  'GOT': 4,
#  'EXAMS': 1,
#  'IN': 14,
#  'MARCH': 1,
#  'IVE': 4,
#  'DONE': 3,
#  'NO': 3,
#  'REVISION?': 1,
#  'IS': 17,
#  'FRAN': 3,
#  'STILL': 1,
#  'WITH': 7,
#  'BOYF?': 1,
#  'GOTTA': 1,
#  'INTERVIW': 1,
#  '4': 95,
#  'EXETER': 1,
#  'BIT': 3,
#  'WORRIED!x': 1,
#  'dont': 60,
#  'use': 18,
#  'hook': 4,
#  'any': 60,
#  'how': 80,
#  'taking': 10,
#  'derek': 2,
#  '&amp;': 35,
#  'taylor': 2,
#  'walmart,': 1,
#  'if': 132,
#  'time': 93,
#  "you're": 29,
#  'done': 10,
#  'just': 132,
#  'leave': 29,
#  'mouse': 1,
#  'desk': 1,
#  'text': 39,
#  'when': 141,
#  "priscilla's": 2,
#  'ready': 17,
#  'de': 7,
#  'shop.': 1,
#  'HIYA': 2,
#  'STU': 1,
#  'WOT': 4,
#  'U': 164,
#  'UP': 15,
#  '2.IM': 1,
#  'SO': 8,
#  'MUCH': 4,
#  'TRUBLE': 1,
#  'AT': 16,
#  'HOME': 3,
#  'MOMENT': 1,
#  'EVONE': 1,
#  'HATES': 1,
#  'ME': 21,
#  'EVEN': 1,
#  'U!': 3,
#  'THE': 19,
#  'HELL': 1,
#  'AV': 1,
#  'NOW?': 1,
#  'Y': 9,
#  'WONT': 1,
#  'JUST': 6,
#  'TELL': 4,
#  'TEXT': 2,
#  'BCK': 1,
#  'PLEASE': 2,
#  'LUV': 4,
#  'DAN': 1,
#  'Hows': 8,
#  'watch': 26,
#  'resizing': 1,
#  'am': 104,
#  'late,so': 1,
#  'tomorrow': 30,
#  'morning.take': 1,
#  'care': 23,
#  'sweet': 13,
#  'dreams....u': 1,
#  'me...ummifying...bye.': 1,
#  'WE': 5,
#  'REGRET': 1,
#  'TO': 7,
#  'INFORM': 1,
#  'THAT': 9,
#  'NHS': 1,
#  'HAS': 1,
#  'MADE': 1,
#  'MISTAKE.U': 1,
#  'WERE': 2,
#  'NEVER': 1,
#  'ACTUALLY': 1,
#  'BORN.PLEASE': 1,
#  'REPORT': 1,
#  'YOR': 2,
#  'LOCAL': 1,
#  'HOSPITAL': 1,
#  '2B': 1,
#  'TERMINATED.WE': 1,
#  'SORRY': 3,
#  'INCONVENIENCE': 1,
#  'Well.': 3,
#  'Im': 13,
#  'computerless.': 1,
#  'Time': 5,
#  'oreo': 2,
#  'truffles': 1,
#  'Lemme': 2,
#  'To': 4,
#  'class': 20,
#  'class.': 9,
#  'Dunno': 16,
#  'lei': 3,
#  'say...': 3,
#  'Hi': 39,
#  'babe': 20,
#  'its': 69,
#  'coming': 25,
#  'even': 27,
#  'though': 9,
#  'didnt': 18,
#  'well!i': 1,
#  'wanted': 17,
#  'bed!': 2,
#  'Hope': 32,
#  'see': 64,
#  'soon': 16,
#  'kisses': 1,
#  'xxx': 6,
#  "I've": 31,
#  'told': 42,
#  'everything': 17,
#  'stop.': 3,
#  'let': 43,
#  'her': 61,
#  'dehydrated.': 1,
#  'Really': 5,
#  'do': 156,
#  'hope': 38,
#  'work': 33,
#  'doesnt': 6,
#  'stressful.': 1,
#  'gr8': 4,
#  'day.': 31,
#  'Is': 33,
#  'ur': 113,
#  'changes': 3,
#  'report': 1,
#  'big?': 1,
#  'Cos': 16,
#  "i've": 18,
#  'made': 15,
#  'previous': 2,
#  'report.': 1,
#  'everywhere': 1,
#  'dirt,': 1,
#  'floor,': 2,
#  'windows,': 1,
#  'shirt.': 1,
#  'And': 67,
#  'sometimes': 2,
#  'open': 9,
#  'mouth,': 1,
#  'all': 133,
#  'comes': 7,
#  'flowing': 2,
#  'out.': 14,
#  'dream': 3,
#  'world': 13,
#  'without': 18,
#  'you,': 24,
#  'then': 94,
#  'half': 12,
#  'chores': 1,
#  'out': 114,
#  'too.': 9,
#  'joy': 1,
#  'me,': 11,
#  'lots': 10,
#  'tv': 13,
#  'shows': 4,
#  'i.ll': 8,
#  'guess': 12,
#  'like': 132,
#  'things': 33,
#  'must': 13,
#  'exist,': 1,
#  'rain,': 1,
#  'hail': 1,
#  'mist,': 1,
#  'done,': 3,
#  'become': 3,
#  'one.': 8,
#  'Wishing': 2,
#  'wonderful': 8,
#  'week.': 10,
#  'Today': 10,
#  'workin': 5,
#  'but': 189,
#  'free': 32,
#  'oso...': 3,
#  'Gee...': 2,
#  'Thgt': 1,
#  'u': 425,
#  "fren's": 1,
#  'shop': 9,
#  '?': 128,
#  'Great!': 4,
#  'How': 98,
#  'office': 11,
#  'today?': 12,
#  'HI': 11,
#  'BABE': 6,
#  'MOST': 2,
#  'LIKELY': 1,
#  'BE': 2,
#  'BED': 2,
#  'BUT': 6,
#  'IM': 14,
#  'ABOUT': 2,
#  'TONIGHT!': 1,
#  'REALLY': 4,
#  'WANNA': 3,
#  'SEE': 3,
#  'TOMORROW': 2,
#  'CALL': 4,
#  '9.': 2,
#  'XXX': 5,
#  'ass!': 1,
#  'enjoy': 11,
#  'doggy': 2,
#  'style?': 1,
#  ':)': 39,
#  'They': 22,
#  "don't": 78,
#  'put': 18,
#  'stuff': 21,
#  'roads': 1,
#  'keep': 39,
#  'from': 99,
#  'getting': 33,
#  'slippery': 1,
#  'over': 32,
#  'there?': 8,
#  'Miss': 6,
#  'miss': 38,
#  'khelate': 1,
#  'kintu': 1,
#  'opponenter': 1,
#  'dhorte': 1,
#  'lage.': 1,
#  'Thats': 9,
#  'rule.': 1,
#  'One': 5,
#  'phone': 35,
#  'receiving': 1,
#  'quality': 2,
#  'wins.': 1,
#  'take': 64,
#  "didn't": 30,
#  'callon': 1,
#  'Friday.': 1,
#  'Can': 44,
#  'assume': 2,
#  "won't": 12,
#  'year': 12,
#  'now?': 17,
#  'feel?': 1,
#  'Mr.': 1,
#  'real': 15,
#  'Valentine': 3,
#  'yo': 5,
#  'tho': 4,
#  'hardly': 2,
#  'play!!': 1,
#  'What': 60,
#  'pa': 3,
#  'me..': 4,
#  'bath:-)': 1,
#  'Edison': 1,
#  'has': 45,
#  'rightly': 1,
#  'said,': 2,
#  '\\A': 1,
#  'fool': 3,
#  'ask': 53,
#  'questions': 4,
#  'wise': 2,
#  'man': 11,
#  'answer\\"': 1,
#  'Now': 14,
#  'us': 34,
#  'speechless': 1,
#  'during': 6,
#  'ViVa..': 1,
#  'GM': 1,
#  'I\x89Û÷m': 4,
#  'going': 88,
#  'try': 20,
#  'months': 5,
#  'ha': 7,
#  'only': 66,
#  'joking': 2,
#  'now...': 6,
#  'Ard': 6,
#  '6': 11,
#  'dat': 23,
#  'K': 20,
#  'sure': 37,
#  'consent': 1,
#  'forms': 1,
#  ':V': 5,
#  'I.ll': 15,
#  'hand': 3,
#  'chat': 7,
#  'wit': 10,
#  'still': 84,
#  'meeting': 21,
#  'dinner': 14,
#  'tonight?': 7,
#  'Lmao!nice': 1,
#  '1': 21,
#  'Boo': 2,
#  'moms.': 2,
#  "She's": 4,
#  'making': 17,
#  'tortilla': 2,
#  'soup.': 1,
#  'Yummmm': 1,
#  'Pls': 28,
#  'she': 51,
#  'needs': 12,
#  'slowly': 4,
#  'vomit': 2,
#  'more.': 2,
#  '&lt;#&gt;': 178,
#  'g': 7,
#  'saw': 11,
#  'few': 25,
#  'days': 13,
#  'ago,': 1,
#  'guy': 15,
#  'wants': 10,
#  'sell': 6,
#  'wifi': 2,
#  '3g': 2,
#  '.': 118,
#  "That's": 13,
#  'blanked': 1,
#  'him.': 5,
#  'close': 7,
#  'stubborn': 1,
#  'am.': 3,
#  'want': 92,
#  'hospital.': 3,
#  'kept': 4,
#  'telling': 10,
#  'Mark': 3,
#  'weak': 3,
#  'sucker.': 1,
#  'Hospitals': 1,
#  'suckers.': 1,
#  'they': 56,
#  'oredi': 3,
#  'not...': 1,
#  'ÌÏ': 31,
#  'v': 18,
#  'ma': 2,
#  'fan...': 1,
#  'Ì_': 65,
#  'decide': 6,
#  'faster': 3,
#  'liao..': 1,
#  'Wot': 5,
#  '2?': 2,
#  'Thout': 1,
#  'me!!': 2,
#  'Txt': 3,
#  'bak': 4,
#  'luv': 13,
#  'where': 36,
#  'lab': 4,
#  'goggles': 1,
#  'afternoon,': 7,
#  'goes': 23,
#  'did': 43,
#  'well,': 6,
#  'boytoy': 10,
#  'think': 83,
#  'ard': 9,
#  'christmas.': 2,
#  'merry': 1,
#  "x'mas.": 1,
#  'min:)': 3,
#  'Its': 44,
#  'site': 4,
#  'simulate': 1,
#  'test.': 2,
#  'It': 37,
#  'gives': 4,
#  'very': 47,
#  'tough': 5,
#  'test': 13,
#  'readiness.': 1,
#  'shall': 11,
#  'fine.': 10,
#  'avalarr': 1,
#  'now.': 35,
#  'Will': 20,
#  'hollalater': 1,
#  'do.': 14,
#  'Was': 12,
#  'exhausted': 2,
#  'train': 5,
#  'morning.': 10,
#  'Too': 3,
#  'much': 60,
#  'wine': 5,
#  'pie.': 1,
#  'too': 47,
#  'Dear': 20,
#  'sore': 1,
#  'throat.': 1,
#  "It's": 26,
#  'scratches': 1,
#  'talk': 16,
#  'God': 6,
#  'created': 2,
#  'gap': 3,
#  'btwn': 1,
#  'fingers': 2,
#  'sum1': 1,
#  'vry': 2,
#  'fill': 3,
#  'those': 17,
#  'gaps': 1,
#  'holding': 2,
#  'hands..': 1,
#  'plz': 7,
#  'y': 13,
#  'between': 10,
#  'legs': 2,
#  '!!!': 4,
#  'already..sabarish': 1,
#  'asked': 11,
#  'go..': 1,
#  'sense': 3,
#  'unless': 5,
#  'free.': 3,
#  'If': 73,
#  'need': 92,
#  'more,': 1,
#  'wikipedia.com': 1,
#  'years': 9,
#  'missed': 13,
#  'friendship:-)': 1,
#  'Check': 3,
#  'mail.i': 1,
#  'mailed': 1,
#  'varma': 1,
#  'copy': 4,
#  'regarding': 3,
#  'membership.take': 1,
#  'care.insha': 1,
#  'allah.': 1,
#  'Hi.': 6,
#  '||': 8,
#  '|': 5,
#  'join': 8,
#  'sts': 1,
#  'later?': 6,
#  'Meeting': 2,
#  'them': 42,
#  'five.': 1,
#  'Call': 12,
#  'after': 45,
#  'Thanks': 20,
#  'My': 46,
#  'trip': 11,
#  'was': 125,
#  'quite': 23,
#  'tiring': 1,
#  'Uni': 1,
#  'starts': 4,
#  "it's": 30,
#  'modules': 2,
#  'jus': 15,
#  'concentrating': 1,
#  'final': 1,
#  'yr': 3,
#  'project.': 3,
#  'Probably': 7,
#  'not,': 6,
#  'almost': 8,
#  'gas': 9,
#  'cash': 7,
#  'Ok.': 14,
#  'many': 32,
#  'should': 48,
#  'buy.': 2,
#  'wondering': 4,
#  'would': 50,
#  'okay': 2,
#  'uncle': 4,
#  'john': 3,
#  'nigeria': 3,
#  'r': 69,
#  'here.': 8,
#  'That': 23,
#  'dollars': 2,
#  '2years': 1,
#  'sent': 34,
#  'strain': 1,
#  'plan': 12,
#  'every': 25,
#  'dime': 2,
#  'gives.': 1,
#  'Every': 5,
#  'expect': 3,
#  'anything': 37,
#  'practical.': 1,
#  'Something': 3,
#  'that.': 15,
#  'bold': 5,
#  'bb': 4,
#  'torch': 3,
#  'Pick': 2,
#  'bout': 9,
#  '7.30ish?': 1,
#  'going?': 5,
#  'Alrite': 1,
#  'jod': 1,
#  'hows': 3,
#  'revision': 1,
#  'goin?': 2,
#  'Keris': 1,
#  'bin': 4,
#  'doin': 3,
#  'smidgin.': 1,
#  'N': 6,
#  'wanna': 14,
#  'cum': 4,
#  'college?xx': 1,
#  'live': 7,
#  'because': 20,
#  'smokes': 1,
#  'spend': 4,
#  'hours': 7,
#  'begging': 2,
#  'come': 120,
#  'smoke': 15,
#  'Free': 2,
#  'mon': 2,
#  'thurs...': 1,
#  'Yar': 8,
#  'lor': 19,
#  'wan': 40,
#  'c': 29,
#  'horse': 1,
#  'racing': 2,
#  'mah,': 1,
#  'earlier': 4,
#  'ate': 3,
#  'chicken': 3,
#  'rice.': 1,
#  'U?': 5,
#  'Everybody': 1,
#  'fun': 12,
#  'evening.': 1,
#  'you.': 47,
#  'Hi,': 5,
#  'wkend': 1,
#  'journey': 1,
#  'terrible.': 1,
#  'Wk': 2,
#  'huge': 2,
#  'log': 5,
#  'marking': 1,
#  'Congratulations': 1,
#  'ore': 1,
#  'mo': 3,
#  'owo': 1,
#  're': 6,
#  'wa.': 1,
#  'Enjoy': 5,
#  'happy': 26,
#  'moments': 2,
#  'fro': 1,
#  'wherever': 5,
#  'Yeah,': 10,
#  'lined': 1,
#  'thank': 8,
#  'selflessness.': 1,
#  'plenty.': 1,
#  'studying': 3,
#  'home?': 2,
#  'Anyway': 5,
#  "i'll": 24,
#  'later.': 19,
#  'ELLO': 1,
#  'OK?': 1,
#  'Piggy,': 1,
#  'awake?': 2,
#  'bet': 4,
#  "u're": 4,
#  'sleeping.': 2,
#  'drive': 9,
#  'sch.': 1,
#  'S': 4,
#  'da..al': 1,
#  'above': 1,
#  'Yep,': 2,
#  'loxahatchee': 2,
#  'xmas': 2,
#  'burning': 2,
#  'an': 53,
#  'hour': 17,
#  'Lul': 1,
#  'im': 24,
#  'gettin': 5,
#  'juicy': 2,
#  'gossip': 1,
#  'Two': 3,
#  'nurses': 1,
#  'fat': 3,
#  'gettin.': 1,
#  'thinks': 3,
#  'shes': 1,
#  'obese.': 1,
#  'Oyea.': 1,
#  'We': 55,
#  'okay.': 7,
#  'Going': 12,
#  'Later': 4,
#  'Hi..i': 1,
#  'money': 25,
#  'da:)': 4,
#  'anymore.': 3,
#  'nothing': 11,
#  'else': 6,
#  'say.': 1,
#  'imma': 4,
#  'definitely': 5,
#  'restock': 1,
#  'thanksgiving,': 1,
#  'Btw': 2,
#  'anyone': 9,
#  'our': 35,
#  '4th': 1,
#  'commit': 1,
#  'random': 2,
#  'dude': 3,
#  'Oh': 38,
#  'great.': 2,
#  'disturb': 6,
#  'talk.': 2,
#  'Whens': 1,
#  'radio': 2,
#  'show?': 1,
#  'alright': 7,
#  'babe?': 1,
#  'worry': 9,
#  'might': 17,
#  'felt': 7,
#  'bit': 21,
#  'desparate': 2,
#  'learned': 1,
#  'job': 15,
#  'fake': 1,
#  'back,': 3,
#  'Sun': 2,
#  'cant': 32,
#  'earth': 3,
#  'rays.': 1,
#  'cloud': 1,
#  'river': 1,
#  'rain.': 1,
#  'meet': 41,
#  'U,': 2,
#  'msg': 22,
#  'U.': 2,
#  'Gud': 18,
#  'evng': 3,
#  'hi': 24,
#  'baby': 8,
#  'cruisin': 1,
#  'girl': 12,
#  'give': 60,
#  'thats': 13,
#  'fone': 4,
#  'jenny': 1,
#  'Nothing': 8,
#  'msgs': 3,
#  'dis': 18,
#  'name': 13,
#  'different': 4,
#  "no's..": 1,
#  'Jus': 11,
#  'blowing': 1,
#  'hair.': 2,
#  'already?': 9,
#  'read': 6,
#  'shame': 1,
#  'takes': 11,
#  'runs': 2,
#  'blame': 1,
#  'ever!!': 1,
#  'Not': 36,
#  'ever': 16,
#  'Okey': 3,
#  'doke.': 1,
#  'home,': 2,
#  'dressed': 2,
#  'laying': 1,
#  'ill!': 1,
#  'Speak': 7,
#  'stuff.': 3,
#  'Auntie': 1,
#  'huai': 1,
#  'juan': 1,
#  'never': 20,
#  'ARE': 8,
#  'TOWN?': 1,
#  'THIS': 10,
#  'V.': 2,
#  'IMPORTANT': 1,
#  'ic.': 1,
#  'meant': 8,
#  'mary': 1,
#  'jane.': 1,
#  'dont.': 2,
#  'Plus': 7,
#  "how's": 11,
#  'mode.': 1,
#  'completely': 4,
#  'forgot': 14,
#  '*': 23,
#  'pop': 1,
#  'round': 4,
#  'week': 23,
#  'here?': 5,
#  'Nobody': 2,
#  'names': 1,
#  'their': 8,
#  'penis': 1,
#  'girls': 5,
#  'story': 4,
#  ...}

# %% [markdown]
# ## creating the model using Naïve Bayes formula

# %%
def find_words(mail):
    words = []
    for word in mail.split():
        if word not in words:
            words.append(word)
    return words

# %%
## Probability of spam & ham
hamlen = len(y_train[y_train=="ham"])
spamlen = len(y_train[y_train=="spam"])
p_ham = hamlen/(hamlen+spamlen)
p_spam = spamlen/(hamlen+spamlen)
print(p_ham,p_spam)
# Out:
# 0.8736871199557766 0.12631288004422334

# %%
## Probability of all words
p_all_words = {}
for k1,v1 in freq_spam.items():
        p_all_words[k1] = v1/total_all_words

# %%
## Probability of word in spam list 
p_word_in_spam = {}
for k1,v1 in freq_spam.items():
        p_word_in_spam[k1] = v1/total_spam

# %%
## Probability of word in spam list 
p_word_in_ham = {}
for k1,v1 in freq_ham.items():
        p_word_in_ham[k1] = v1/total_ham

# %%
def naive_bayes_prob_spam(mail):
    words = find_words(mail)
    prob = 1
    p_word = 1
    for word in words:
        if word in p_word_in_spam:
            prob*=p_word_in_spam[word]
        else: 
            prob*=0.000000000000001
            
        if word in p_all_words:
            p_word*= p_all_words[word]
        else:
            p_word*=1
    return (prob*p_spam)/p_word

# %%
def naive_bayes_prob_ham(mail):
    words = find_words(mail)
    prob = 1
    p_word = 1
    for word in words:
        if word in p_word_in_ham:
            prob*=p_word_in_ham[word]
        else: 
            prob*=0.000000000000001
            
        if word in p_all_words:
            p_word*= p_all_words[word]
        else:
            p_word*=1
    return (prob*p_ham)/p_word

# %%
def predicted_prob(mail):
    prob_being_ham = naive_bayes_prob_ham(mail)
    prob_being_spam = naive_bayes_prob_spam(mail)
    return prob_being_spam,prob_being_ham

# %% [markdown]
# ## Testing the modal

# %%
for i,test_mail in enumerate(X_test):
    pred_prob_spam,pred_prob_ham = predicted_prob(test_mail)
    if pred_prob_spam>=pred_prob_ham:
        print(test_mail)
        print("Predicted spam with prob:",pred_prob_spam)
        print("Actual y:",y_test[i])
# Out:
# Free tones Hope you enjoyed your new content. text stop to 61610 to unsubscribe. help:08712400602450p Provided by tones2you.co.uk
# Predicted spam with prob: 163490898655.38776
# Actual y: spam
# 18 days to Euro2004 kickoff! U will be kept informed of all the latest news and results daily. Unsubscribe send GET EURO STOP to 83222.
# Predicted spam with prob: 4.349508286641213e-63
# Actual y: spam
# Todays Voda numbers ending 7548 are selected to receive a $350 award. If you have a match please call 08712300220 quoting claim code 4041 standard rates app
# Predicted spam with prob: 3.078458658924416e-30
# Actual y: spam
# PRIVATE! Your 2003 Account Statement for shows 800 un-redeemed S. I. M. points. Call 08718738002 Identifier Code: 48922 Expires 21/11/04
# Predicted spam with prob: 1.6349089865538807e-34
# Actual y: spam
# Hi. Customer Loyalty Offer:The NEW Nokia6650 Mobile from ONLY å£10 at TXTAUCTION! Txt word: START to No: 81151 & get yours Now! 4T&Ctxt TC 150p/MTmsg
# Predicted spam with prob: 15.87839555040472
# Actual y: spam
# 3 FREE TAROT TEXTS! Find out about your love life now! TRY 3 FOR FREE! Text CHANCE to 85555 16 only! After 3 Free, Msgs å£1.50 each
# Predicted spam with prob: 4.349508286641212e-78
# Actual y: spam
# Do you want a New Nokia 3510i Colour Phone Delivered Tomorrow? With 200 FREE minutes to any mobile + 100 FREE text + FREE camcorder Reply or Call 08000930705
# Predicted spam with prob: 4.2242848741461894e+17
# Actual y: spam
# URGENT! Your Mobile number has been awarded with a å£2000 prize GUARANTEED. Call 09061790121 from land line. Claim 3030. Valid 12hrs only 150ppm
# Predicted spam with prob: 0.5968429042231004
# Actual y: spam
# Panasonic & BluetoothHdset FREE. Nokia FREE. Motorola FREE & DoubleMins & DoubleTxt on Orange contract. Call MobileUpd8 on 08000839402 or call 2optout
# Predicted spam with prob: 2.309938502602733e-67
# Actual y: spam
# Congratulations ur awarded 500 of CD vouchers or 125gift guaranteed & Free entry 2 100 wkly draw txt MUSIC to 87066 TnCs www.Ldew.com1win150ppmx3age16
# Predicted spam with prob: 3078458658924415.0
# Actual y: spam
# FreeMsg Today's the day if you are ready! I'm horny & live in your town. I love sex fun & games! Netcollex Ltd 08700621170150p per msg reply Stop to end
# Predicted spam with prob: 4.224284874146192e-28
# Actual y: spam
# HOT LIVE FANTASIES call now 08707509020 Just 20p per min NTT Ltd, PO Box 1327 Croydon CR9 5WB 0870..k
# Predicted spam with prob: 0.0008432704302251012
# Actual y: spam
# Great NEW Offer - DOUBLE Mins & DOUBLE Txt on best Orange tariffs AND get latest camera phones 4 FREE! Call MobileUpd8 free on 08000839402 NOW! or 2stoptxt T&Cs
# Predicted spam with prob: 3.0784586589244166e-45
# Actual y: spam
# SPJanuary Male Sale! Hot Gay chat now cheaper, call 08709222922. National rate from 1.5p/min cheap to 7.8p/min peak! To stop texts call 08712460324 (10p/min)
# Predicted spam with prob: 8.682680816797215e-174
# Actual y: spam
# FREE camera phones with linerental from 4.49/month with 750 cross ntwk mins. 1/2 price txt bundle deals also avble. Call 08001950382 or call2optout/J MF
# Predicted spam with prob: 1.6349089865538794e-79
# Actual y: spam
# URGENT! We are trying to contact U. Todays draw shows that you have won a å£800 prize GUARANTEED. Call 09050001808 from land line. Claim M95. Valid12hrs only
# Predicted spam with prob: 8.189924672992102e-14
# Actual y: spam
# Buy Space Invaders 4 a chance 2 win orig Arcade Game console. Press 0 for Games Arcade (std WAP charge) See o2.co.uk/games 4 Terms + settings. No purchase
# Predicted spam with prob: 3.1697155485472473e-140
# Actual y: spam
# Someone has conacted our dating service and entered your phone because they fancy you!To find out who it is call from landline 09111030116. PoBox12n146tf15
# Predicted spam with prob: 4.3495082866412126e-63
# Actual y: spam
# Todays Voda numbers ending 1225 are selected to receive a å£50award. If you have a match please call 08712300220 quoting claim code 3100 standard rates app
# Predicted spam with prob: 3.078458658924415e-15
# Actual y: spam
# Urgent! Please call 09061213237 from landline. å£5000 cash or a luxury 4* Canary Islands Holiday await collection. T&Cs SAE PO Box 177. M227XY. 150ppm. 16+
# Predicted spam with prob: 1.1571422318398952e-46
# Actual y: spam
# U can WIN å£100 of Music Gift Vouchers every week starting NOW Txt the word DRAW to 87066 TsCs www.ldew.com SkillGame,1Winaweek, age16.150ppermessSubscription
# Predicted spam with prob: 2.3099385026027322e-127
# Actual y: spam
# Please call Amanda with regard to renewing or upgrading your current T-Mobile handset free of charge. Offer ends today. Tel 0845 021 3680 subject to T's and C's
# Predicted spam with prob: 8.432704302251017e-124
# Actual y: spam
# Hello from Orange. For 1 month's free access to games, news and sport, plus 10 free texts and 20 photo messages, reply YES. Terms apply: www.orange.co.uk/ow
# Predicted spam with prob: 2.243434805428971e-47
# Actual y: spam
# Congratulations! Thanks to a good friend U have WON the å£2,000 Xmas prize. 2 claim is easy, just call 08718726971 NOW! Only 10p per minute. BT-national-rate.
# Predicted spam with prob: 81.89924672992099
# Actual y: spam
# Message Important information for O2 user. Today is your lucky day! 2 find out why log onto http://www.urawinner.com there is a fantastic surprise awaiting you
# Predicted spam with prob: 3.078458658924416
# Actual y: spam
# YOU 07801543489 are guaranteed the latests Nokia Phone, a 40GB iPod MP3 player or a å£500 prize! Txt word:COLLECT to No:83355! TC-LLC NY-USA 150p/Mt msgrcvd18+
# Predicted spam with prob: 3.169715548547249e-110
# Actual y: spam
# You have won ?1,000 cash or a ?2,000 prize! To claim, call09050000327. T&C: RSTM, SW7 3SS. 150ppm
# Predicted spam with prob: 1.191444203257573e-36
# Actual y: spam
# Romantic Paris. 2 nights, 2 flights from å£79 Book now 4 next year. Call 08704439680Ts&Cs apply.
# Predicted spam with prob: 6.327526371797737e-101
# Actual y: spam
# Guess what! Somebody you know secretly fancies you! Wanna find out who it is? Give us a call on 09065394973 from Landline DATEBox1282EssexCM61XN 150p/min 18
# Predicted spam with prob: 15.87839555040473
# Actual y: spam
# Update_Now - Xmas Offer! Latest Motorola, SonyEricsson & Nokia & FREE Bluetooth! Double Mins & 1000 Txt on Orange. Call MobileUpd8 on 08000839402 or call2optout/F4Q=
# Predicted spam with prob: 2.243434805428971e-17
# Actual y: spam
# We currently have a message awaiting your collection. To collect your message just call 08718723815.
# Predicted spam with prob: 4.478443783785835e-08
# Actual y: spam
# As a registered optin subscriber ur draw 4 å£100 gift voucher will be entered on receipt of a correct ans to 80062 Whats No1 in the BBC charts
# Predicted spam with prob: 5.9684290422310036e-61
# Actual y: spam
# URGENT This is our 2nd attempt to contact U. Your å£900 prize from YESTERDAY is still awaiting collection. To claim CALL NOW 09061702893. ACL03530150PM
# Predicted spam with prob: 1.1571422318398948e-16
# Actual y: spam
# Marvel Mobile Play the official Ultimate Spider-man game (å£4.50) on ur mobile right now. Text SPIDER to 83338 for the game & we ll send u a FREE 8Ball wallpaper
# Predicted spam with prob: 4.349508286641214e-123
# Actual y: spam
# You have been specially selected to receive a 2000 pound award! Call 08712402050 BEFORE the lines close. Cost 10ppm. 16+. T&Cs apply. AG Promo
# Predicted spam with prob: 5.968429042231e-16
# Actual y: spam
# We know TAJ MAHAL as symbol of love. But the other lesser known facts 1. Mumtaz was Shahjahan's 4th wife, out of his 7 wifes. 2. Shahjahan killed Mumtaz's husband to marry her. 3. Mumtaz died in her  &lt;#&gt; th delivery. 4. He then married Mumtaz's sister. Question arises where the Hell is the LOVE?:-| -The Great Hari-
# Predicted spam with prob: 0.0
# Actual y: ham
# SMS AUCTION - A BRAND NEW Nokia 7250 is up 4 auction today! Auction is FREE 2 join & take part! Txt NOKIA to 86021 now!
# Predicted spam with prob: 8.189924672992102e+16
# Actual y: spam
# You have an important customer service announcement from PREMIER. Call FREEPHONE 0800 542 0578 now!
# Predicted spam with prob: 6145355332.519037
# Actual y: spam
# Congratulations ur awarded either å£500 of CD gift vouchers & Free entry 2 our å£100 weekly draw txt MUSIC to 87066 TnCs www.Ldew.com 1 win150ppmx3age16
# Predicted spam with prob: 3.078458658924415e-15
# Actual y: spam
# Someone has contacted our dating service and entered your phone because they fancy you! To find out who it is call from a landline 09111032124 . PoBox12n146tf150p
# Predicted spam with prob: 1.587839555040473e-29
# Actual y: spam
# ou are guaranteed the latest Nokia Phone, a 40GB iPod MP3 player or a å£500 prize! Txt word: COLLECT to No: 83355! IBHltd LdnW15H 150p/Mtmsgrcvd18
# Predicted spam with prob: 3.0784586589244154
# Actual y: spam
# 5 Free Top Polyphonic Tones call 087018728737, National Rate. Get a toppoly tune sent every week, just text SUBPOLY to 81618, å£3 per pole. UnSub 08718727870.
# Predicted spam with prob: 3.1697155485472487e-140
# Actual y: spam
# As a valued customer, I am pleased to advise you that following recent review of your Mob No. you are awarded with a å£1500 Bonus Prize, call 09066364589
# Predicted spam with prob: 81.89924672992105
# Actual y: spam
# HOT LIVE FANTASIES call now 08707500020 Just 20p per min NTT Ltd, PO Box 1327 Croydon CR9 5WB 0870 is a national rate call
# Predicted spam with prob: 0.5968429042230999
# Actual y: spam
# Moby Pub Quiz.Win a å£100 High Street prize if u know who the new Duchess of Cornwall will be? Txt her first name to 82277.unsub STOP å£1.50 008704050406 SP Arrow
# Predicted spam with prob: 57965.965033212604
# Actual y: spam
# Please call our customer service representative on 0800 169 6031 between 10am-9pm as you have WON a guaranteed å£1000 cash or å£5000 prize!
# Predicted spam with prob: 2.243434805428971e-32
# Actual y: spam
# If you don't, your prize will go to another customer. T&C at www.t-c.biz 18+ 150p/min Polo Ltd Suite 373 London W1J 6HL Please call back if busy
# Predicted spam with prob: 2.1788457660405993e+18
# Actual y: spam
# 1000's flirting NOW! Txt GIRL or BLOKE & ur NAME & AGE, eg GIRL ZOE 18 to 8007 to join and get chatting!
# Predicted spam with prob: 1.1914442032575739e-81
# Actual y: spam
# You are being contacted by our dating service by someone you know! To find out who it is, call from a land line 09050000878. PoBox45W2TG150P
# Predicted spam with prob: 3.078458658924414
# Actual y: spam
# u r subscribed 2 TEXTCOMP 250 wkly comp. 1st wk?s free question follows, subsequent wks charged@150p/msg.2 unsubscribe txt STOP 2 84128,custcare 08712405020
# Predicted spam with prob: 4.47844378378584e-128
# Actual y: spam
# Eerie Nokia tones 4u, rply TONE TITLE to 8007 eg TONE DRACULA to 8007 Titles: GHOST, ADDAMSFA, MUNSTERS, EXORCIST, TWILIGHT www.getzed.co.uk POBox36504W45WQ 150p
# Predicted spam with prob: 22434348054289.715
# Actual y: spam
# You've won tkts to the EURO2004 CUP FINAL or å£800 CASH, to collect CALL 09058099801 b4190604, POBOX 7876150ppm
# Predicted spam with prob: 3.263677629574711e-115
# Actual y: spam
# **FREE MESSAGE**Thanks for using the Auction Subscription Service. 18 . 150p/MSGRCVD 2 Skip an Auction txt OUT. 2 Unsubscribe txt STOP CustomerCare 08718726270
# Predicted spam with prob: 4.4784437837858414e-113
# Actual y: spam
# Bears Pic Nick, and Tom, Pete and ... Dick. In fact, all types try gay chat with photo upload call 08718730666 (10p/min). 2 stop texts call 08712460324
# Predicted spam with prob: 3.1697155485472467e-125
# Actual y: spam
# Sexy Singles are waiting for you! Text your AGE followed by your GENDER as wither M or F E.G.23F. For gay men text your AGE followed by a G. e.g.23G.
# Predicted spam with prob: 1.6349089865538785e-109
# Actual y: spam
# FreeMsg: Txt: CALL to No: 86888 & claim your reward of 3 hours talk time to use from your phone now! Subscribe6GBP/mnth inc 3hrs 16 stop?txtStop
# Predicted spam with prob: 8.432704302251019e-79
# Actual y: spam
# U can WIN å£100 of Music Gift Vouchers every week starting NOW Txt the word DRAW to 87066 TsCs www.Idew.com SkillGame, 1Winaweek, age16. 150ppermessSubscription
# Predicted spam with prob: 2.3099385026027325e-157
# Actual y: spam
# XMAS Prize draws! We are trying to contact U. Todays draw shows that you have won a å£2000 prize GUARANTEED. Call 09058094565 from land line. Valid 12hrs only
# Predicted spam with prob: 2178.845766040601
# Actual y: spam
# As a SIM subscriber, you are selected to receive a Bonus! Get it delivered to your door, Txt the word OK to No: 88600 to claim. 150p/msg, EXP. 30Apr
# Predicted spam with prob: 1.6349089865538787e-109
# Actual y: spam
# You have WON a guaranteed å£1000 cash or a å£2000 prize.To claim yr prize call our customer service representative on
# Predicted spam with prob: 0.0008432704302251016
# Actual y: spam
# Sunshine Hols. To claim ur med holiday send a stamped self address envelope to Drinks on Us UK, PO Box 113, Bray, Wicklow, Eire. Quiz Starts Saturday! Unsub Stop
# Predicted spam with prob: 6.1453553325190406e-201
# Actual y: spam
# This is the 2nd attempt to contract U, you have won this weeks top prize of either å£1000 cash or å£200 prize. Just call 09066361921
# Predicted spam with prob: 3.078458658924416e-15
# Actual y: spam
# This is the 2nd time we have tried to contact u. U have won the å£400 prize. 2 claim is easy, just call 087104711148 NOW! Only 10p per minute. BT-national-rate
# Predicted spam with prob: 422.4284874146191
# Actual y: spam
# No but the bluray player can
# Predicted spam with prob: 4.611201405485326e-13
# Actual y: ham
# Txt: CALL to No: 86888 & claim your reward of 3 hours talk time to use from your phone now! Subscribe6GBP/mnth inc 3hrs 16 stop?txtStop www.gamb.tv
# Predicted spam with prob: 1.6349089865538794e-94
# Actual y: spam
# Had your mobile 10 mths? Update to the latest Camera/Video phones for FREE. KEEP UR SAME NUMBER, Get extra free mins/texts. Text YES for a call
# Predicted spam with prob: 1.1571422318398947e-46
# Actual y: spam
# FreeMsg Hi baby wow just got a new cam moby. Wanna C a hot pic? or Fancy a chat?Im w8in 4uTxt / rply CHAT to 82242 Hlp 08712317606 Msg150p 2rcv
# Predicted spam with prob: 2.2434348054289703e-107
# Actual y: spam
# WIN a å£200 Shopping spree every WEEK Starting NOW. 2 play text STORE to 88039. SkilGme. TsCs08714740323 1Winawk! age16 å£1.50perweeksub.
# Predicted spam with prob: 1.191444203257573e-81
# Actual y: spam
# FREE entry into our å£250 weekly comp just send the word ENTER to 84128 NOW. 18 T&C www.textcomp.com cust care 08712405020.
# Predicted spam with prob: 0.022434348054289715
# Actual y: spam
# \URGENT! This is the 2nd attempt to contact U!U have WON å£1000CALL 09071512432 b4 300603t&csBCM4235WC1N3XX.callcost150ppmmobilesvary. maxå£7. 50\""
# Predicted spam with prob: 4.478443783785839e-68
# Actual y: spam
# Back 2 work 2morro half term over! Can U C me 2nite 4 some sexy passion B4 I have 2 go back? Chat NOW 09099726481 Luv DENA Calls å£1/minMobsmoreLKPOBOX177HP51FL
# Predicted spam with prob: 1.63490898655388e-154
# Actual y: spam
# Kit Strip - you have been billed 150p. Netcollex Ltd. PO Box 1013 IG11 OJA
# Predicted spam with prob: 3.263677629574709e-85
# Actual y: spam
# 2p per min to call Germany 08448350055 from your BT line. Just 2p per min. Check PlanetTalkInstant.com for info & T's & C's. Text stop to opt out
# Predicted spam with prob: 4.349508286641211e-63
# Actual y: spam
# Get your garden ready for summer with a FREE selection of summer bulbs and seeds worth å£33:50 only with The Scotsman this Saturday. To stop go2 notxt.co.uk
# Predicted spam with prob: 3.1697155485472467e-125
# Actual y: spam
# u r a winner U ave been specially selected 2 receive å£1000 cash or a 4* holiday (flights inc) speak to a live operator 2 claim 0871277810710p/min (18 )
# Predicted spam with prob: 5.968429042231002e-46
# Actual y: spam
# Natalie (20/F) is inviting you to be her friend. Reply YES-165 or NO-165 See her: www.SMS.ac/u/natalie2k9 STOP? Send STOP FRND to 62468
# Predicted spam with prob: 3.169715548547247e-65
# Actual y: spam
# FREE RING TONE just text \POLYS\" to 87131. Then every week get a new tone. 0870737910216yrs only å£1.50/wk."
# Predicted spam with prob: 4.478443783785837e-83
# Actual y: spam
# For sale - arsenal dartboard. Good condition but no doubles or trebles!
# Predicted spam with prob: 1.2267630118546094e-71
# Actual y: spam
# WIN URGENT! Your mobile number has been awarded with a å£2000 prize GUARANTEED call 09061790121 from land line. claim 3030 valid 12hrs only 150ppm
# Predicted spam with prob: 1.157142231839895e-31
# Actual y: spam
# we tried to contact you re your response to our offer of a new nokia fone and camcorder hit reply or call 08000930705 for delivery
# Predicted spam with prob: 3.078458658924413
# Actual y: spam
# SMS. ac Blind Date 4U!: Rodds1 is 21/m from Aberdeen, United Kingdom. Check Him out http://img. sms. ac/W/icmb3cktz8r7!-4 no Blind Dates send HIDE
# Predicted spam with prob: 6.327526371797744e-206
# Actual y: spam
# Congratulations ur awarded either a yrs supply of CDs from Virgin Records or a Mystery Gift GUARANTEED Call 09061104283 Ts&Cs www.smsco.net å£1.50pm approx 3mins
# Predicted spam with prob: 6.145355332519041e-111
# Actual y: spam
# Urgent! Please call 09061743811 from landline. Your ABTA complimentary 4* Tenerife Holiday or å£5000 cash await collection SAE T&Cs Box 326 CW25WX 150ppm
# Predicted spam with prob: 0.5968429042231006
# Actual y: spam
# Congrats! 1 year special cinema pass for 2 is yours. call 09061209465 now! C Suprman V, Matrix3, StarWars3, etc all 4 FREE! bx420-ip4-5we. 150pm. Dont miss out!
# Predicted spam with prob: 2.1788457660406e+18
# Actual y: spam
# Win a å£1000 cash prize or a prize worth å£5000
# Predicted spam with prob: 63275.26371797731
# Actual y: spam
# Ee msg na poortiyagi odalebeku: Hanumanji 7 name 1-Hanuman 2-Bajarangabali 3-Maruti 4-Pavanaputra 5-Sankatmochan 6-Ramaduth 7-Mahaveer ee 7 name  &lt;#&gt;  janarige ivatte kalisidare next saturday olage ondu good news keluviri...! Maretare inde 1 dodda problum nalli siguviri idu matra  &lt;#&gt; % true.. Don't neglet.
# Predicted spam with prob: 0.0
# Actual y: ham
# 500 New Mobiles from 2004, MUST GO! Txt: NOKIA to No: 89545 & collect yours today!From ONLY å£1 www.4-tc.biz 2optout 087187262701.50gbp/mtmsg18
# Predicted spam with prob: 115714223183989.48
# Actual y: spam
# Your 2004 account for 07XXXXXXXXX shows 786 unredeemed points. To claim call 08719181259 Identifier code: XXXXX Expires 26.03.05
# Predicted spam with prob: 2.3099385026027328e-67
# Actual y: spam
# January Male Sale! Hot Gay chat now cheaper, call 08709222922. National rate from 1.5p/min cheap to 7.8p/min peak! To stop texts call 08712460324 (10p/min)
# Predicted spam with prob: 8.682680816797215e-174
# Actual y: spam
# Please CALL 08712402578 immediately as there is an urgent message waiting for you
# Predicted spam with prob: 4.478443783785839e-08
# Actual y: spam
# YOU ARE CHOSEN TO RECEIVE A å£350 AWARD! Pls call claim number 09066364311 to collect your award which you are selected to receive as a valued mobile customer.
# Predicted spam with prob: 5.9684290422309974e-61
# Actual y: spam
# Hungry gay guys feeling hungry and up 4 it, now. Call 08718730555 just 10p/min. To stop texts call 08712460324 (10p/min)
# Predicted spam with prob: 6.14535533251904e-66
# Actual y: spam
# (Bank of Granite issues Strong-Buy) EXPLOSIVE PICK FOR OUR MEMBERS *****UP OVER 300% *********** Nasdaq Symbol CDGT That is a $5.00 per..
# Predicted spam with prob: 596842904223099.6
# Actual y: spam
# important information 4 orange user . today is your lucky day!2find out why log onto http://www.urawinner.com THERE'S A FANTASTIC SURPRISE AWAITING YOU!
# Predicted spam with prob: 596842904223100.2
# Actual y: spam
# You have 1 new message. Please call 08715205273
# Predicted spam with prob: 1.2267630118546083e-11
# Actual y: spam
# You have won ?1,000 cash or a ?2,000 prize! To claim, call09050000327
# Predicted spam with prob: 3.2636776295747073e-40
# Actual y: spam
# Claim a 200 shopping spree, just call 08717895698 now! Have you won! MobStoreQuiz10ppm
# Predicted spam with prob: 6.327526371797738e-71
# Actual y: spam
# Want a new Video Phone? 750 anytime any network mins? Half price line rental free text for 3 months? Reply or call 08000930705 for free delivery
# Predicted spam with prob: 5.968429042230994e-16
# Actual y: spam
# Think ur smart ? Win å£200 this week in our weekly quiz, text PLAY to 85222 now!T&Cs WinnersClub PO BOX 84, M26 3UZ. 16+. GBP1.50/week
# Predicted spam with prob: 3.169715548547249e-125
# Actual y: spam
# Here is your discount code RP176781. To stop further messages reply stop. www.regalportfolio.co.uk. Customer Services 08717205546
# Predicted spam with prob: 8.682680816797213e-69
# Actual y: spam
# Do you want a new Video phone? 600 anytime any network mins 400 Inclusive Video calls AND downloads 5 per week Free delTOMORROW call 08002888812 or reply NOW
# Predicted spam with prob: 5.968429042231002e-61
# Actual y: spam
# WINNER! As a valued network customer you hvae been selected to receive a å£900 reward! To collect call 09061701444. Valid 24 hours only. ACL03530150PM
# Predicted spam with prob: 8.432704302251013e-64
# Actual y: spam
# FREE2DAY sexy St George's Day pic of Jordan!Txt PIC to 89080 dont miss out, then every wk a saucy celeb!4 more pics c PocketBabe.co.uk 0870241182716 å£3/wk
# Predicted spam with prob: 3.1697155485472478e-140
# Actual y: spam
# U have won a nokia 6230 plus a free digital camera. This is what u get when u win our FREE auction. To take part send NOKIA to 83383 now. POBOX114/14TCR/W1 16
# Predicted spam with prob: 8.189924672992115e-59
# Actual y: spam
# Urgent Please call 09066612661 from landline. å£5000 cash or a luxury 4* Canary Islands Holiday await collection. T&Cs SAE award. 20M12AQ. 150ppm. 16+ ÛÏ
# Predicted spam with prob: 4.349508286641213e-63
# Actual y: spam
# URGENT! Your mobile No *********** WON a å£2,000 Bonus Caller Prize on 02/06/03! This is the 2nd attempt to reach YOU! Call 09066362220 ASAP! BOX97N7QP, 150ppm
# Predicted spam with prob: 81.89924672992105
# Actual y: spam
# You have WON a guaranteed å£1000 cash or a å£2000 prize. To claim yr prize call our customer service representative on 08714712379 between 10am-7pm Cost 10p
# Predicted spam with prob: 15.878395550404722
# Actual y: spam
# Free Msg: Ringtone!From: http://tms. widelive.com/index. wml?id=1b6a5ecef91ff9*37819&first=true18:0430-JUL-05
# Predicted spam with prob: 1.7332751473982225e-44
# Actual y: spam
# URGENT!! Your 4* Costa Del Sol Holiday or å£5000 await collection. Call 09050090044 Now toClaim. SAE, TC s, POBox334, Stockport, SK38xh, Costå£1.50/pm, Max10mins
# Predicted spam with prob: 0.5968429042231002
# Actual y: spam
# Congrats! 2 mobile 3G Videophones R yours. call 09061744553 now! videochat wid ur mates, play java games, Dload polyH music, noline rentl. bx420. ip4. 5we. 150pm
# Predicted spam with prob: 1.587839555040472e-14
# Actual y: spam
# This weeks SavaMob member offers are now accessible. Just call 08709501522 for details! SavaMob, POBOX 139, LA3 2WU. Only å£1.50/week. SavaMob - offers mobile!
# Predicted spam with prob: 6.145355332519038e-96
# Actual y: spam
# You have won a guaranteed 32000 award or maybe even å£1000 cash to claim ur award call free on 0800 ..... (18+). Its a legitimat efreefone number wat do u think???
# Predicted spam with prob: 5.968429042231001e-91
# Actual y: spam
# U are subscribed to the best Mobile Content Service in the UK for å£3 per ten days until you send STOP to 83435. Helpline 08706091795.
# Predicted spam with prob: 2.2434348054289713e-32
# Actual y: spam
# FREE for 1st week! No1 Nokia tone 4 ur mob every week just txt NOKIA to 8007 Get txting and tell ur mates www.getzed.co.uk POBox 36504 W45WQ norm150p/tone 16+
# Predicted spam with prob: 1.1238278226092868e+19
# Actual y: spam
# Ur HMV Quiz cash-balance is currently å£500 - to maximize ur cash-in now send HMV1 to 86688 only 150p/msg
# Predicted spam with prob: 3.1697155485472476e-20
# Actual y: spam
# She is our sister.. She belongs 2 our family.. She is d hope of tomorrow.. Pray 4 her,who was fated 4 d Shoranur train incident. Lets hold our hands together &amp; fuelled by love &amp; concern prior 2 her grief &amp; pain. Pls join in dis chain &amp; pass it. STOP VIOLENCE AGAINST WOMEN.
# Predicted spam with prob: 0.0
# Actual y: ham
# Free msg. Sorry, a service you ordered from 81303 could not be delivered as you do not have sufficient credit. Please top up to receive the service.
# Predicted spam with prob: 5.9684290422310005e-31
# Actual y: spam
# FreeMsg>FAV XMAS TONES!Reply REAL
# Predicted spam with prob: 3.360425093875775e-30
# Actual y: spam
# Ur cash-balance is currently 500 pounds - to maximize ur cash-in now send COLLECT to 83600 only 150p/msg. CC: 08718720201 PO BOX 114/14 TCR/W1
# Predicted spam with prob: 3078458658924416.0
# Actual y: spam
# Gr8 new service - live sex video chat on your mob - see the sexiest dirtiest girls live on ur phone - 4 details text horny to 89070 to cancel send STOP to 89070
# Predicted spam with prob: 1.5878395550404728e-29
# Actual y: spam
# Orange customer, you may now claim your FREE CAMERA PHONE upgrade for your loyalty. Call now on 0207 153 9996. Offer ends 14thMarch. T&C's apply. Opt-out availa
# Predicted spam with prob: 5.968429042230998e-31
# Actual y: spam
# You are guaranteed the latest Nokia Phone, a 40GB iPod MP3 player or a å£500 prize! Txt word: COLLECT to No: 83355! IBHltd LdnW15H 150p/Mtmsgrcvd18+
# Predicted spam with prob: 3.078458658924415
# Actual y: spam
# 09066362231 URGENT! Your mobile No 07xxxxxxxxx won a å£2,000 bonus caller prize on 02/06/03! this is the 2nd attempt to reach YOU! call 09066362231 ASAP!
# Predicted spam with prob: 1.5878395550404718e+16
# Actual y: spam
# Customer service annoncement. You have a New Years delivery waiting for you. Please call 07046744435 now to arrange delivery
# Predicted spam with prob: 6.14535533251903e-36
# Actual y: spam
# FREE UNLIMITED HARDCORE PORN direct 2 your mobile Txt PORN to 69200 & get FREE access for 24 hrs then chrgd@50p per day txt Stop 2exit. This msg is free
# Predicted spam with prob: 5.968429042231004e-76
# Actual y: spam
# PRIVATE! Your 2003 Account Statement for 078
# Predicted spam with prob: 2.3784136150933443e-12
# Actual y: spam
# Adult 18 Content Your video will be with you shortly
# Predicted spam with prob: 6.327526371797733e-26
# Actual y: spam
# Hey...Great deal...Farm tour 9am to 5pm $95/pax, $50 deposit by 16 May
# Predicted spam with prob: 8.940067558903271e-119
# Actual y: ham
# A å£400 XMAS REWARD IS WAITING FOR YOU! Our computer has randomly picked you from our loyal mobile customers to receive a å£400 reward. Just call 09066380611
# Predicted spam with prob: 4.22428487414619e+17
# Actual y: spam
# Get the official ENGLAND poly ringtone or colour flag on yer mobile for tonights game! Text TONE or FLAG to 84199. Optout txt ENG STOP Box39822 W111WX å£1.50
# Predicted spam with prob: 3.169715548547248e-155
# Actual y: spam
# Collect your VALENTINE'S weekend to PARIS inc Flight & Hotel + å£200 Prize guaranteed! Text: PARIS to No: 69101. www.rtf.sphosting.com
# Predicted spam with prob: 6.327526371797732e-146
# Actual y: spam
# Get 3 Lions England tone, reply lionm 4 mono or lionp 4 poly. 4 more go 2 www.ringtones.co.uk, the original n best. Tones 3GBP network operator rates apply.
# Predicted spam with prob: 4.2242848741461914e+17
# Actual y: spam
# Please CALL 08712402779 immediately as there is an urgent message waiting for you
# Predicted spam with prob: 4.478443783785839e-08
# Actual y: spam
# Ur cash-balance is currently 500 pounds - to maximize ur cash-in now send CASH to 86688 only 150p/msg. CC: 08718720201 PO BOX 114/14 TCR/W1
# Predicted spam with prob: 3078458658924416.5
# Actual y: spam
# Sorry! U can not unsubscribe yet. THE MOB offer package has a min term of 54 weeks> pls resubmit request after expiry. Reply THEMOB HELP 4 more info
# Predicted spam with prob: 1.6349089865538784e-154
# Actual y: spam
# Ringtone Club: Get the UK singles chart on your mobile each week and choose any top quality ringtone! This message is free of charge.
# Predicted spam with prob: 5.968429042231005e-16
# Actual y: spam
# Call Germany for only 1 pence per minute! Call from a fixed line via access number 0844 861 85 85. No prepayment. Direct access! www.telediscount.co.uk
# Predicted spam with prob: 3.0784586589244136
# Actual y: spam
# U were outbid by simonwatson5120 on the Shinco DVD Plyr. 2 bid again, visit sms. ac/smsrewards 2 end bid notifications, reply END OUT
# Predicted spam with prob: 2.3099385026027327e-112
# Actual y: spam
# U have a Secret Admirer who is looking 2 make contact with U-find out who they R*reveal who thinks UR so special-call on 09065171142-stopsms-08718727870150ppm
# Predicted spam with prob: 0.11571422318398941
# Actual y: spam
# We tried to contact you re your reply to our offer of a Video Phone 750 anytime any network mins Half Price Line Rental Camcorder Reply or call 08000930705
# Predicted spam with prob: 1.1238278226092853e+19
# Actual y: spam
# Sunshine Quiz Wkly Q! Win a top Sony DVD player if u know which country Liverpool played in mid week? Txt ansr to 82277. å£1.50 SP:Tyrone
# Predicted spam with prob: 3.0784586589244144e-30
# Actual y: spam
# Santa Calling! Would your little ones like a call from Santa Xmas eve? Call 09058094583 to book your time.
# Predicted spam with prob: 1.1914442032575731e-36
# Actual y: spam
# XMAS iscoming & ur awarded either å£500 CD gift vouchers & free entry 2 r å£100 weekly draw txt MUSIC to 87066 TnC www.Ldew.com1win150ppmx3age16subscription
# Predicted spam with prob: 0.5968429042230999
# Actual y: spam
# Urgent! call 09066350750 from your landline. Your complimentary 4* Ibiza Holiday or 10,000 cash await collection SAE T&Cs PO BOX 434 SK3 8WP 150 ppm 18+
# Predicted spam with prob: 4.224284874146194e+17
# Actual y: spam
# Hi 07734396839 IBH Customer Loyalty Offer: The NEW NOKIA6600 Mobile from ONLY å£10 at TXTAUCTION!Txt word:START to No:81151 & get Yours Now!4T&
# Predicted spam with prob: 2.3099385026027334e-127
# Actual y: spam
# Well done ENGLAND! Get the official poly ringtone or colour flag on yer mobile! text TONE or FLAG to 84199 NOW! Opt-out txt ENG STOP. Box39822 W111WX å£1.50
# Predicted spam with prob: 3.1697155485472476e-155
# Actual y: spam
# WOW! The Boys R Back. TAKE THAT 2007 UK Tour. Win VIP Tickets & pre-book with VIP Club. Txt CLUB to 81303. Trackmarque Ltd info@vipclub4u.
# Predicted spam with prob: 2.3099385026027316e-157
# Actual y: spam
# Summers finally here! Fancy a chat or flirt with sexy singles in yr area? To get MATCHED up just reply SUMMER now. Free 2 Join. OptOut txt STOP Help08714742804
# Predicted spam with prob: 1.1571422318398959e-106
# Actual y: spam
# What do U want for Xmas? How about 100 free text messages & a new video phone with half price line rental? Call free now on 0800 0721072 to find out more!
# Predicted spam with prob: 1.1238278226092845e-26
# Actual y: spam
# Latest Nokia Mobile or iPOD MP3 Player +å£400 proze GUARANTEED! Reply with: WIN to 83355 now! Norcorp Ltd.å£1,50/Mtmsgrcvd18+
# Predicted spam with prob: 1.6833737299399246e-114
# Actual y: spam
# Todays Voda numbers ending with 7634 are selected to receive a å£350 reward. If you have a match please call 08712300220 quoting claim code 7684 standard rates apply.
# Predicted spam with prob: 8.189924672992104e-14
# Actual y: spam
# Loan for any purpose å£500 - å£75,000. Homeowners + Tenants welcome. Have you been previously refused? We can still help. Call Free 0800 1956669 or text back 'help'
# Predicted spam with prob: 4.349508286641214e-123
# Actual y: spam
# YOU HAVE WON! As a valued Vodafone customer our computer has picked YOU to win a å£150 prize. To collect is easy. Just call 09061743386
# Predicted spam with prob: 3078458658924413.0
# Actual y: spam
# Double mins and txts 4 6months FREE Bluetooth on Orange. Available on Sony, Nokia Motorola phones. Call MobileUpd8 on 08000839402 or call2optout/N9DX
# Predicted spam with prob: 6.14535533251904e-66
# Actual y: spam
# URGENT We are trying to contact you Last weekends draw shows u have won a å£1000 prize GUARANTEED Call 09064017295 Claim code K52 Valid 12hrs 150p pm
# Predicted spam with prob: 3.078458658924414e-45
# Actual y: spam
# You will be receiving this week's Triple Echo ringtone shortly. Enjoy it!
# Predicted spam with prob: 3.263677629574708e-40
# Actual y: spam
# 85233 FREE>Ringtone!Reply REAL
# Predicted spam with prob: 6.51509763380664e-31
# Actual y: spam
# One day a crab was running on the sea shore..The waves came n cleared the footprints of the crab.. Crab asked: being my frnd y r u clearing my beautiful footprints? Waves replied: A fox was following ur footprints to catch you! thats y i cleared it off:) frndsship never lets u dwn :-) GUD nyt..
# Predicted spam with prob: 0.0
# Actual y: ham
# URGENT! Your Mobile number has been awarded with a å£2000 prize GUARANTEED. Call 09058094454 from land line. Claim 3030. Valid 12hrs only
# Predicted spam with prob: 0.1157142231839895
# Actual y: spam
# Sad story of a Man - Last week was my b'day. My Wife did'nt wish me. My Parents forgot n so did my Kids . I went to work. Even my Colleagues did not wish. As I entered my cabin my PA said, '' Happy B'day Boss !!''. I felt special. She askd me 4 lunch. After lunch she invited me to her apartment. We went there. She said,'' do u mind if I go into the bedroom for a minute ? '' ''OK'', I sed in a sexy mood. She came out 5 minuts latr wid a cake...n My Wife, My Parents, My Kidz, My Friends n My Colleagues. All screaming.. SURPRISE !! and I was waiting on the sofa.. ... ..... ' NAKED...!
# Predicted spam with prob: 0.0
# Actual y: ham
# It,,s a taxt massage....tie-pos argh ok! Lool!
# Predicted spam with prob: 3.360425093875777e-75
# Actual y: ham
# URGENT! We are trying to contact U. Todays draw shows that you have won a å£800 prize GUARANTEED. Call 09050003091 from land line. Claim C52. Valid 12hrs only
# Predicted spam with prob: 1.1238278226092845e+19
# Actual y: spam
# FREE NOKIA Or Motorola with upto 12mths 1/2price linerental, 500 FREE x-net mins&100txt/mth FREE B'tooth*. Call Mobileupd8 on 08001950382 or call 2optout/D3WV
# Predicted spam with prob: 4.4784437837858414e-113
# Actual y: spam
# URGENT! Your Mobile number has been awarded a <UKP>2000 prize GUARANTEED. Call 09061790125 from landline. Claim 3030. Valid 12hrs only 150ppm
# Predicted spam with prob: 4.349508286641211e-18
# Actual y: spam
# wamma get laid?want real doggin locations sent direct to your mobile? join the UKs largest dogging network. txt dogs to 69696 now!nyt. ec2a. 3lp å£1.50/msg.
# Predicted spam with prob: 3.169715548547248e-110
# Actual y: spam
# Congrats! Nokia 3650 video camera phone is your Call 09066382422 Calls cost 150ppm Ave call 3mins vary from mobiles 16+ Close 300603 post BCM4284 Ldn WC1N3XX
# Predicted spam with prob: 8.432704302251013e-109
# Actual y: spam
# HMV BONUS SPECIAL 500 pounds of genuine HMV vouchers to be won. Just answer 4 easy questions. Play Now! Send HMV to 86688 More info:www.100percent-real.com
# Predicted spam with prob: 1.1914442032575743e-111
# Actual y: spam
# Fancy a shag? I do.Interested? sextextuk.com txt XXUK SUZY to 69876. Txts cost 1.50 per msg. TnCs on website. X
# Predicted spam with prob: 4.4784437837858426e-113
# Actual y: spam
# We know someone who you know that fancies you. Call 09058097218 to find out who. POBox 6, LS15HB 150p
# Predicted spam with prob: 3.169715548547246e-20
# Actual y: spam
# Thank you, winner notified by sms. Good Luck! No future marketing reply STOP to 84122 customer services 08450542832
# Predicted spam with prob: 8.68268081679722e-99
# Actual y: spam

# %% [markdown]
# ## Finding accuracy

# %%
c = 0
for i,test_mail in enumerate(X_test):
    pred_prob_spam,pred_prob_ham = predicted_prob(test_mail)
    if pred_prob_spam>=pred_prob_ham and y_test[i]=="spam":
        c=c+1
    elif pred_prob_spam<=pred_prob_ham and y_test[i]=="ham":
        c=c+1
print(c/len(y_test))
# Out:
# 0.9761444229529336

# %% [markdown]
# ## Create a confusion matrix on our prediction for test dataset

# %%
#True positives
#Assuming spam = 1 and ham = 0
tp,tn, fp,fn=0,0,0,0
for i,test_mail in enumerate(X_test):
    pred_prob_spam,pred_prob_ham = predicted_prob(test_mail)
    if pred_prob_spam>=pred_prob_ham and y_test[i]=="spam":
        tp=tp+1
    elif pred_prob_spam<=pred_prob_ham and y_test[i]=="ham":
        tn=tn+1
    elif pred_prob_spam>=pred_prob_ham and y_test[i]=="ham":
        fp=fp+1
    elif pred_prob_spam<=pred_prob_ham and y_test[i]=="spam":
        fn=fn+1
pd.DataFrame(data = [[tp,fn],[fp,tn]],index=["Actual Yes", "Actual No"], columns=["Predicted Yes", "Predicted No"])
# Out:
#             Predicted Yes  Predicted No
# Actual Yes            162            34
# Actual No               3          1352

# %%
recall = tp/(tp+fn)
precision = tp/(tp+fp)
f1_score = 2*precision*recall/(precision+recall)
print("Recall:", recall)
print("Precision:", precision)
print("F1 score:", f1_score)
# Out:
# Recall: 0.826530612244898
# Precision: 0.9818181818181818
# F1 score: 0.8975069252077562
